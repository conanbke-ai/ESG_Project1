# %% [markdown]
# # XGBoost 시계열 예측 파이프라인 구조 요약
#
# ---
#
# ## 1. 전체 파이프라인
#
# 1. **데이터 로드**
#    - `train`, `val`, `test` CSV 파일 로드
#    - `일시` 컬럼을 `datetime` 형식으로 변환하여 시계열로 처리
#
# 2. **테이블 빌드**
#    - 시간 특징(`hour`, `doy`, sin/cos) 생성
#    - `lag_k` 및 `diff_past_k` 생성
#    - 다음 24시간 합계 타깃(`target_next_24h`) 생성
#    - 결측 제거 및 0으로 채움
#    → `build_table()`에서 통합 수행
#
# 3. **지역별 스케일링 학습**
#    - 입력 특징: `StandardScaler → MinMaxScaler`
#    - 타깃: `log1p` 후 `StandardScaler`
#    - 지역 단위 스케일러 세트(`region_scalers`) 생성 및 저장
#
# 4. **스케일 변환 적용**
#    - `transform_frame()`을 통해 지역별 스케일러를
#      `train`, `val`, `test` 데이터에 적용
#
# 5. **Plant 1차 학습**
#    - 발전소 단위로 XGBoost 모델 학습
#    - 에포크 단위 부스팅 + EMA 기반 조기 종료
#    - Best 모델(`best.json`) 저장
#    → `train_epochal()` 사용
#
# 6. **Region 파인튜닝(2차 학습)**
#    - 지역 단위로 fine-tuning 수행
#    - 성능이 가장 높은 발전소 모델로 warm start
#    - 동일한 부스팅 및 조기 종료 전략 사용
#
# 7. **시간대 편향 보정**
#    - `compute_hour_bias()`로 검증 구간의 시간(`hour`)별 평균 잔차 계산
#    - `apply_hour_bias()`로 시간대별 보정 적용 (보정량은 `CALIB_CLIP` 비율 제한)
#
# 8. **검증 성능 요약**
#    - 발전소(`df_plant`), 지역(`df_region`), 지역 보정(`df_region_post`) 단위의 성능 표 생성
#    - R², RMSE, MAE 포함
#
# 9. **테스트 평가**
#    - 발전소별 모델 및 지역별 모델로 Test 성능 계산
#    - 보정 전·후 성능 비교
#
# 10. **가중 평균 계산**
#     - 표본 수 기반 가중 평균 계산
#     - 검증 및 테스트 각각 R², RMSE, MAE 출력
#     → `_weighted_avg()` 사용
#
# 11. **체크포인트 관리**
#     - 모델 학습 중 생성된 파일 관리
#     - `best.json`, `last.json`, `checkpoint.json` 유지
#     - UTF-16 등 비정상 파일은 자동 제외
#
# ---
#
# ## 2. 단계별 주요 함수
#
# | 구분 | 함수명 | 기능 요약 |
# |------|---------|------------|
# | **테이블 빌드** | `add_time_feats` | `hour`, `doy` 기반 sin/cos 생성 |
# |  | `add_lag_only` | 그룹별 lag_k 생성 |
# |  | `add_past_deltas` | lag_1 - lag_(k+1) 계산 |
# |  | `make_next24_target` | 24시간 합계 타깃 생성 |
# |  | `build_table` | 위 모든 단계 일괄 처리 |
# | **스케일링** | `transform_frame` | 지역별 스케일러 적용 |
# |  | `inverse_target` | 예측값을 MWh 단위로 복원 |
# | **모델 학습** | `as_dmatrix` | XGBoost용 DMatrix 변환 |
# |  | `train_epochal` | 에포크 기반 부스팅 및 조기 종료 |
# |  | `metrics_mwh` | R², RMSE, MAE 계산 |
# | **보정 및 평가** | `compute_hour_bias` | 시간대별 잔차 계산 |
# |  | `apply_hour_bias` | 보정량 적용 및 음수 방지 |
# | **저장 관리** | `save_booster` | 모델 저장 |
# |  | `load_booster` | 모델 로드 |
# |  | `_file_ok`, `_seems_utf16` | 파일 검증 |
# |  | `_clear_dir_keep3` | 불필요한 체크포인트 삭제 |
# | **평가 요약** | `_weighted_avg` | 가중 평균 계산 |
#
# ---
#
# ## 3. 산출물 요약
#
# | 항목 | 내용 |
# |------|------|
# | **발전소 성능표** | `df_plant` (발전소 단위 R², RMSE, MAE) |
# | **지역 성능표** | `df_region` (지역 단위 R², RMSE, MAE) |
# | **지역 보정 성능표** | `df_region_post` (보정 후 R², RMSE, MAE) |
# | **모델 체크포인트** | 각 발전소·지역별 `best.json`, `last.json`, `checkpoint.json` |
# | **콘솔 출력** | 검증·테스트의 R², RMSE, MAE 가중 평균 결과 |
#
# ---
#
# ## 4. 주요 파라미터
#
# | 변수명 | 설명 |
# |--------|------|
# | `FEATURE_MODE` | 피처 개수 설정 (22 또는 48) |
# | `USE_PAST_DELTAS` | diff_past_k 피처 포함 여부 |
# | `CALIB_CLIP` | 시간대 보정량 상한 비율 |
# | `USE_HOURLY_CALIB` | 시간대별 보정 활성화 여부 |
# | `EPOCHS_PLANT / REGION` | 학습 반복 횟수 |
# | `CKPT_DIR / SAVE_DIR` | 모델 저장 및 출력 폴더 |

# %%
# -*- coding: utf-8 -*-
"""
XGBoost (1주/2주 선택 + 22/48 특징 선택) → 다음 24시간 '합계(MWh)' 예측
- 입력 특징:
  * 22 모드: 기상(10) + 시간(4) + lag(4) + diff(4) = 22
  * 48 모드: 기상(10) + 시간(4) + 대표 lag 17 + 해당 diff 17 = 48
- 타깃: target_next_24h = [t+1 ... t+24] 합계
- 1차: Plant 학습 / 2차: Region 파인튜닝 (warm start)
- Validation-hour 편향 보정만 적용 (앙상블 없음)
- 최종 출력: Valid, Test 각각 Plant / Region / Region(보정) 가중 평균 R²·RMSE·MAE
"""

import os, glob, time, warnings
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

warnings.filterwarnings("ignore")

# =========================
# 경로/기본 설정
# =========================
TRAIN_CSV = r"C:\ESG_Project1\file\merge_data\train.csv"
VAL_CSV   = r"C:\ESG_Project1\file\merge_data\val.csv"
TEST_CSV  = r"C:\ESG_Project1\file\merge_data\test.csv"

SAVE_BASE = r"C:\ESG_Project1\xgboost\output"
os.makedirs(SAVE_BASE, exist_ok=True)

TIME_COL, GROUP_COL, REGION_COL = "일시", "발전구분", "지역"
TARGET_HOURLY = "합산발전량(MWh)"
TARGET_NEXT24 = "target_next_24h"

WEATHER_COLS = [
    "기온(°C)", "강수량(mm)", "풍속(m/s)", "습도(%)", "증기압(hPa)",
    "일조(hr)", "일사(MJ/m2)", "적설(cm)", "전운량(10분위)", "중하층운량(10분위)"
]
TIME_FEATS = ["hour_sin", "hour_cos", "doy_sin", "doy_cos"]

# =========================
# 컨텍스트 / 피처 스위치
# =========================
CONTEXT_2W = False          # False: 1주 컨텍스트, True: 2주
FEATURE_MODE = 22           # {22, 48}
DENSE_2W = False            # 2주 컨텍스트일 때 1~336 dense lag 사용
USE_DELTAS = True           # diff 사용 여부 (48 모드는 자동 True)

def _lags_for_48():
    return [1, 2, 3, 6, 12, 18, 24, 36, 48, 72, 96, 120, 144, 168, 240, 288, 336]

def _resolve_context_lags(context_2w: bool, dense_2w: bool):
    if not context_2w:
        return [1, 3, 6, 24]
    if dense_2w:
        return list(range(1, 337))
    return _lags_for_48()

LAGS_CONTEXT = _resolve_context_lags(CONTEXT_2W, DENSE_2W)

if FEATURE_MODE == 22:
    LAGS_FEATURE = [1, 3, 6, 24]
    USE_PAST_DELTAS = True if USE_DELTAS else False
elif FEATURE_MODE == 48:
    LAGS_FEATURE = _lags_for_48()
    USE_PAST_DELTAS = True
else:
    raise ValueError("FEATURE_MODE must be 22 or 48")

LAGS_BUILD = sorted(set(LAGS_CONTEXT).union(LAGS_FEATURE))

CFG_TAG = f"{'2w' if CONTEXT_2W else '1w'}_feat{FEATURE_MODE}_{'dense' if (CONTEXT_2W and DENSE_2W) else 'rep'}"
SAVE_DIR  = os.path.join(SAVE_BASE, CFG_TAG)
CKPT_DIR  = os.path.join(SAVE_DIR, "checkpoints")
os.makedirs(SAVE_DIR, exist_ok=True)
os.makedirs(CKPT_DIR, exist_ok=True)

print(f"🔧 CONTEXT_2W={CONTEXT_2W}  FEATURE_MODE={FEATURE_MODE}  DENSE_2W={DENSE_2W}  USE_PAST_DELTAS={USE_PAST_DELTAS}")
print(f"🔧 LAGS_CONTEXT size={len(LAGS_CONTEXT)}  LAGS_FEATURE size={len(LAGS_FEATURE)}  LAGS_BUILD size={len(LAGS_BUILD)}")

# =========================
# 스위치(성능 옵션)
# =========================
RESUME = True
USE_HOURLY_CALIB = True     # 시간대별 평균잔차 보정
CALIB_CLIP = 0.25           # 보정량 안전 클립 비율

# =========================
# 하이퍼파라미터 (XGBoost)  ← CNN-BiLSTM 감각에 맞춰 Region 길이만 10 epoch
# =========================
EPOCHS_PLANT = 50
BOOSTS_PER_EPOCH_PLANT = 50
XGB_PARAMS_PLANT = {
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "learning_rate": 0.02,
    "max_depth": 6,
    "min_child_weight": 6,
    "subsample": 0.7,
    "colsample_bytree": 0.7,
    "gamma": 1.0,
    "lambda": 2.0,
    "reg_alpha": 0.5,
    "tree_method": "hist",
}

EPOCHS_REGION = 10             # CNN-BiLSTM 기준에 맞춰 짧게
BOOSTS_PER_EPOCH_REGION = 80
XGB_PARAMS_REGION = {
    **XGB_PARAMS_PLANT,
    "learning_rate": 0.02,     # 동일 감각 유지
    "max_depth": 8,
    "min_child_weight": 8,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "lambda": 4.0,
    "reg_alpha": 0.8,
}
PATIENCE_EPOCHS = 3

EMA_ALPHA = 0.5
MIN_DELTA = 1e-4

# =========================
# 유틸
# =========================
def add_time_feats(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df.sort_values([GROUP_COL, TIME_COL], inplace=True)
    df["hour"] = df[TIME_COL].dt.hour
    df["doy"]  = df[TIME_COL].dt.dayofyear
    df["hour_sin"] = np.sin(2*np.pi*df["hour"]/24)
    df["hour_cos"] = np.cos(2*np.pi*df["hour"]/24)
    df["doy_sin"]  = np.sin(2*np.pi*df["doy"]/365)
    df["doy_cos"]  = np.cos(2*np.pi*df["doy"]/365)
    return df

def add_lag_only(df: pd.DataFrame, lags) -> pd.DataFrame:
    df = df.copy()
    df.sort_values([GROUP_COL, TIME_COL], inplace=True)
    lags_ext = sorted(set(lags + [k+1 for k in lags]))
    for k in lags_ext:
        df[f"lag_{k}"] = df.groupby(GROUP_COL)[TARGET_HOURLY].shift(k)
    return df

def add_past_deltas(df: pd.DataFrame, lags, use_deltas: bool) -> pd.DataFrame:
    df = df.copy()
    if not use_deltas:
        return df
    df.sort_values([GROUP_COL, TIME_COL], inplace=True)
    for k in lags:
        lk = f"lag_{k+1}"
        if "lag_1" in df.columns and lk in df.columns:
            df[f"diff_past_{k}"] = df["lag_1"] - df[lk]
    return df

def make_next24_target(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    g = df.groupby(GROUP_COL)[TARGET_HOURLY]
    df[TARGET_NEXT24] = (
        g.shift(-1).rolling(window=24, min_periods=24).sum().reset_index(level=0, drop=True)
    )
    return df

def build_table(df: pd.DataFrame) -> pd.DataFrame:
    df = add_time_feats(df)
    df = add_lag_only(df, lags=LAGS_BUILD)
    df = add_past_deltas(df, lags=LAGS_BUILD, use_deltas=USE_PAST_DELTAS)
    df = make_next24_target(df)
    df.dropna(subset=[TARGET_NEXT24], inplace=True)
    df.fillna(0.0, inplace=True)
    return df

def as_dmatrix(X, y=None):
    return xgb.DMatrix(X, label=y) if y is not None else xgb.DMatrix(X)

# =========================
# 데이터 로드/구성
# =========================
train_raw = pd.read_csv(TRAIN_CSV, parse_dates=[TIME_COL])
val_raw   = pd.read_csv(VAL_CSV,   parse_dates=[TIME_COL])
test_raw  = pd.read_csv(TEST_CSV,  parse_dates=[TIME_COL])

train_raw = build_table(train_raw)
val_raw   = build_table(val_raw)
test_raw  = build_table(test_raw)

lag_cols_all  = [f"lag_{k}" for k in LAGS_FEATURE]
diff_cols_all = [f"diff_past_{k}" for k in LAGS_FEATURE] if USE_PAST_DELTAS else []
all_candidates = WEATHER_COLS + TIME_FEATS + lag_cols_all + diff_cols_all
feature_cols = [c for c in all_candidates if c in train_raw.columns]

print(f"✅ feature_cols ({len(feature_cols)}): {feature_cols[:16]}{' ...' if len(feature_cols)>16 else ''}")

# =========================
# 지역별 스케일러
# =========================
region_scalers = {}
for region, grp in train_raw.groupby(REGION_COL):
    X = grp[feature_cols].to_numpy(np.float32)
    y = np.log1p(grp[[TARGET_NEXT24]].clip(lower=0.0) + 1e-8)
    std = StandardScaler().fit(X)
    mm  = MinMaxScaler().fit(std.transform(X))
    tsc = StandardScaler().fit(y)
    region_scalers[region] = (std, mm, tsc)

def transform_frame(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for region, grp in df.groupby(REGION_COL):
        if region not in region_scalers:
            continue
        std, mm, tsc = region_scalers[region]
        X = grp[feature_cols].to_numpy(np.float32)
        y = np.log1p(grp[[TARGET_NEXT24]].clip(lower=0.0) + 1e-8)
        df.loc[grp.index, feature_cols] = mm.transform(std.transform(X))
        df.loc[grp.index, TARGET_NEXT24] = tsc.transform(y)
    return df

train = transform_frame(train_raw)
val   = transform_frame(val_raw)
test  = transform_frame(test_raw)

# =========================
# 타깃 역변환 및 메트릭
# =========================
def inverse_target(region: str, y_scaled):
    _, _, tsc = region_scalers[region]
    y_log = tsc.inverse_transform(np.asarray(y_scaled).reshape(-1,1)).ravel()
    y = np.expm1(y_log) - 1e-8
    return np.clip(y, 0, None)

def metrics_mwh(region: str, y_true_scaled, y_pred_scaled):
    y_true = inverse_target(region, y_true_scaled)
    y_pred = inverse_target(region, y_pred_scaled)
    r2  = max(r2_score(y_true, y_pred), 0.0)
    rmse = float(np.sqrt(mean_squared_error(y_true, y_pred)))
    mae  = float(mean_absolute_error(y_true, y_pred))
    return r2, rmse, mae, y_true, y_pred

# =========================
# 안전 저장/재개 유틸
# =========================
def _file_ok(path: str) -> bool:
    try:
        return os.path.exists(path) and os.path.getsize(path) > 0
    except:
        return False

def _seems_utf16(path: str) -> bool:
    try:
        with open(path, "rb") as f:
            head = f.read(8)
        return b"\x00" in head
    except:
        return False

def save_booster(booster: xgb.Booster, path: str):
    os.makedirs(os.path.dirname(path), exist_ok=True
    )
    booster.save_model(path)

def load_booster(path: str):
    if not _file_ok(path) or _seems_utf16(path):
        return None
    try:
        booster = xgb.Booster()
        booster.load_model(path)
        return booster
    except:
        return None

def _clear_dir_keep3(dirpath: str):
    keep = {"best.json", "last.json", "checkpoint.json"}
    if not os.path.isdir(dirpath):
        return
    for p in glob.glob(os.path.join(dirpath, "*")):
        base = os.path.basename(p)
        if base not in keep and os.path.isfile(p):
            try:
                os.remove(p)
            except:
                pass

# =========================
# 에포크 학습 루틴 (XGBoost)
# =========================
def train_epochal(
    name,
    dtrain,
    dvalid,
    region,
    y_valid_scaled,
    work_dir,
    epochs,
    boosts_per_epoch,
    params,
    patience_epochs,
    init_model_path=None,
    ema_alpha=EMA_ALPHA,
    min_delta=MIN_DELTA,
):
    os.makedirs(work_dir, exist_ok=True)
    path_best = os.path.join(work_dir, "best.json")
    path_last = os.path.join(work_dir, "last.json")
    path_ckpt = os.path.join(work_dir, "checkpoint.json")

    ema = None
    best_ema = -float("inf")
    best_rounds = 0
    early_counter = 0
    booster = None

    for cand in [path_ckpt, path_last, init_model_path]:
        if cand and _file_ok(cand) and not _seems_utf16(cand):
            booster = load_booster(cand)
            if booster is not None:
                print(f"🔄 Resume from: {cand}")
                break

    wall_start = time.time()
    base_rounds = booster.num_boosted_rounds() if booster is not None else 0
    total_target_rounds = epochs * boosts_per_epoch

    for ep in range(1, epochs+1):
        booster = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=boosts_per_epoch,
            xgb_model=booster,
            evals=[(dvalid, "valid")],
            verbose_eval=False
        )
        now_rounds = booster.num_boosted_rounds()

        try:
            y_pred_scaled = booster.predict(dvalid, iteration_range=(0, now_rounds))
        except TypeError:
            y_pred_scaled = booster.predict(dvalid)

        r2, rmse, mae, _, _ = metrics_mwh(region, y_valid_scaled, y_pred_scaled)
        ema = r2 if ema is None else (ema_alpha * r2 + (1 - ema_alpha) * ema)

        improved = (ema - best_ema) > min_delta
        best_mark = ""
        if improved:
            best_ema = ema
            best_rounds = now_rounds
            save_booster(booster, path_best)
            best_mark = "★Best★"
            early_counter = 0
        else:
            early_counter += 1

        elapsed = time.time() - wall_start
        done_rounds = max(1, now_rounds - base_rounds)
        avg_per_round = elapsed / done_rounds
        remain_rounds = max(0, total_target_rounds - now_rounds)
        eta = avg_per_round * remain_rounds
        eta_str = f"{eta/60:.2f}m" if eta >= 60 else f"{eta:.1f}s"

        print(f"Epoch {ep}/{epochs} | Val R2={r2:.4f} | EMA R2={ema:.4f} {best_mark} | RMSE={rmse:.4f} | MAE={mae:.4f} | ETA={eta_str}")

        save_booster(booster, path_last)
        save_booster(booster, path_ckpt)
        _clear_dir_keep3(work_dir)

        if early_counter >= patience_epochs:
            print(f"⏹ EarlyStopping Triggered (best_rounds={best_rounds})")
            break

    final_path = path_best if _file_ok(path_best) else path_last
    final = load_booster(final_path)
    if final is not None:
        try:
            y_pred_scaled = final.predict(dvalid, iteration_range=(0, final.num_boosted_rounds()))
        except TypeError:
            y_pred_scaled = final.predict(dvalid)
        r2, rmse, mae, _, _ = metrics_mwh(region, y_valid_scaled, y_pred_scaled)
        print(f"✅ {name} 평가 완료 | R2={r2:.4f} | RMSE={rmse:.4f} | MAE={mae:.4f}")
    else:
        print(f"⚠️ 최종 모델 로드 실패: {final_path}")
        y_pred_scaled = booster.predict(dvalid)
        r2, rmse, mae, _, _ = metrics_mwh(region, y_valid_scaled, y_pred_scaled)
        save_booster(booster, path_best)
        final_path = path_best
        print(f"✅ {name} 평가 완료(대체) | R2={r2:.4f} | RMSE={rmse:.4f} | MAE={mae:.4f}")

    return final_path, (r2, rmse, mae)

# =========================
# 1) Plant 1차 학습
# =========================
plant_models_1st = {}
plant_val_scores = {}

for plant, df_tr in train.groupby(GROUP_COL):
    df_va = val[val[GROUP_COL] == plant]
    if len(df_tr) == 0 or len(df_va) == 0:
        print(f"⚠ {plant}: 데이터 없음. 스킵")
        continue

    X_tr = df_tr[feature_cols].to_numpy(np.float32)
    y_tr = df_tr[TARGET_NEXT24].to_numpy(np.float32)
    X_va = df_va[feature_cols].to_numpy(np.float32)
    y_va = df_va[TARGET_NEXT24].to_numpy(np.float32)
    region = df_va[REGION_COL].iloc[0] if len(df_va) else df_tr[REGION_COL].iloc[0]

    dtrain = as_dmatrix(X_tr, y_tr)
    dvalid = as_dmatrix(X_va, y_va)
    work_dir = os.path.join(CKPT_DIR, "plant", plant)
    init_model = os.path.join(work_dir, "best.json") if (RESUME and os.path.exists(os.path.join(work_dir, "best.json"))) else None

    print(f"\n🌱 Plant 1차 학습 시작: {plant} | train size: {len(df_tr)}")
    if init_model: print(f"🔄 Resume: {init_model}")

    best_path, metrics = train_epochal(
        name=f"Plant {plant}",
        dtrain=dtrain, dvalid=dvalid,
        region=region, y_valid_scaled=y_va,
        work_dir=work_dir,
        epochs=EPOCHS_PLANT, boosts_per_epoch=BOOSTS_PER_EPOCH_PLANT,
        params=XGB_PARAMS_PLANT,
        patience_epochs=1,
        init_model_path=init_model
    )

    plant_models_1st[plant] = best_path
    plant_val_scores[plant]  = dict(region=region, r2=metrics[0], rmse=metrics[1], mae=metrics[2])

# =========================
# 2) Region 파인튜닝 (warm start)
# =========================
region_models = {}
region_metrics = {}
region_seed_path = {}

for region, df_tr_region in train.groupby(REGION_COL):
    df_va_region = val[val[REGION_COL] == region]
    if len(df_tr_region) == 0 or len(df_va_region) == 0:
        print(f"⚠ Region {region}: 데이터 없음. 스킵"); continue

    X_tr = df_tr_region[feature_cols].to_numpy(np.float32)
    y_tr = df_tr_region[TARGET_NEXT24].to_numpy(np.float32)
    X_va = df_va_region[feature_cols].to_numpy(np.float32)
    y_va = df_va_region[TARGET_NEXT24].to_numpy(np.float32)

    dtrain = as_dmatrix(X_tr, y_tr)
    dvalid = as_dmatrix(X_va, y_va)

    plants_in_region = df_tr_region[GROUP_COL].unique().tolist()
    cand = [(p, plant_val_scores.get(p, {}).get("r2", -1)) for p in plants_in_region]
    cand.sort(key=lambda x: x[1], reverse=True)
    seed_model_path = plant_models_1st.get(cand[0][0], None) if cand else None

    work_dir = os.path.join(CKPT_DIR, "region", region)
    if RESUME and os.path.exists(os.path.join(work_dir, "best.json")):
        init_model = os.path.join(work_dir, "best.json")
        print(f"\n🌿 Region {region} 재개")
    else:
        init_model = seed_model_path
        print(f"\n🌿 Region {region} warm start: {init_model}")

    best_path, metrics = train_epochal(
        name=f"Region {region}",
        dtrain=dtrain, dvalid=dvalid,
        region=region, y_valid_scaled=y_va,
        work_dir=work_dir,
        epochs=EPOCHS_REGION, boosts_per_epoch=BOOSTS_PER_EPOCH_REGION,
        params=XGB_PARAMS_REGION,
        patience_epochs=PATIENCE_EPOCHS,
        init_model_path=init_model
    )
    region_models[region] = best_path
    region_metrics[region] = metrics
    region_seed_path[region] = seed_model_path  # Warm-start 기록

# =========================
# 3) Validation-hour 편향 보정
# =========================
def compute_hour_bias(region, booster, df_val_region):
    if df_val_region.empty: return {}
    Xv = df_val_region[feature_cols].to_numpy(np.float32)
    yv = df_val_region[TARGET_NEXT24].to_numpy(np.float32)
    dv = as_dmatrix(Xv)
    y_pred_scaled = booster.predict(dv)
    _, _, _, y_true, y_pred = metrics_mwh(region, yv, y_pred_scaled)
    hours = df_val_region["hour"].to_numpy()
    df_tmp = pd.DataFrame({"hour": hours, "y_true": y_true, "y_pred": y_pred})
    df_tmp["res"] = df_tmp["y_true"] - df_tmp["y_pred"]
    return df_tmp.groupby("hour")["res"].mean().to_dict()

def apply_hour_bias(region, y_pred, hours, bias_dict):
    if not USE_HOURLY_CALIB or not bias_dict: return y_pred
    y_adj = y_pred.copy()
    for i, h in enumerate(hours):
        b = bias_dict.get(int(h), 0.0)
        cap = max(1e-8, abs(y_adj[i]) * CALIB_CLIP)
        b = max(-cap, min(cap, b))
        y_adj[i] = max(0.0, y_adj[i] + b)
    return y_adj

region_post_metrics = {}
region_hour_bias = {}

for region, model_path in region_models.items():
    booster_region = load_booster(model_path)
    if booster_region is None: continue

    df_va_region = val[val[REGION_COL] == region].copy()
    if df_va_region.empty: continue

    Xv = df_va_region[feature_cols].to_numpy(np.float32)
    yv = df_va_region[TARGET_NEXT24].to_numpy(np.float32)
    dv = as_dmatrix(Xv)
    y_pred_r_scaled = booster_region.predict(dv)
    r2_r, rmse_r, mae_r, y_true_r, y_pred_r = metrics_mwh(region, yv, y_pred_r_scaled)

    bias = compute_hour_bias(region, booster_region, df_va_region) if USE_HOURLY_CALIB else {}
    hours = df_va_region["hour"].to_numpy()
    y_pred_r_cal = apply_hour_bias(region, y_pred_r, hours, bias)
    region_hour_bias[region] = bias

    r2_b  = max(r2_score(y_true_r, y_pred_r_cal), 0.0)
    rmse_b= float(np.sqrt(mean_squared_error(y_true_r, y_pred_r_cal)))
    mae_b = float(mean_absolute_error(y_true_r, y_pred_r_cal))

    region_post_metrics[region] = dict(
        r2_region=r2_r, rmse_region=rmse_r, mae_region=mae_r,
        r2_post=r2_b, rmse_post=rmse_b, mae_post=mae_b
    )

# =========================
# 4) 요약 테이블 구성
# =========================
df_plant = pd.DataFrame([
    {"plant": k, "region": v.get("region"), "val_r2": v.get("r2"), "val_rmse": v.get("rmse"), "val_mae": v.get("mae")}
    for k, v in plant_val_scores.items()
])

df_region = pd.DataFrame([
    {"region": r, "val_r2": m[0], "val_rmse": m[1], "val_mae": m[2]}
    for r, m in region_metrics.items()
])

df_region_post = pd.DataFrame([
    {"region": r, **m} for r, m in region_post_metrics.items()
])

# =========================
# 5) Test 평가 (Plant/Region, 보정)
# =========================
plant_test_rows = []
for plant, df_te in test.groupby(GROUP_COL):
    region = df_te[REGION_COL].iloc[0]
    model_path = plant_models_1st.get(plant)
    if not model_path: continue
    booster = load_booster(model_path)
    if booster is None or len(df_te) == 0: continue

    Xte = df_te[feature_cols].to_numpy(np.float32)
    yte = df_te[TARGET_NEXT24].to_numpy(np.float32)
    dte = as_dmatrix(Xte)
    try:
        y_pred_scaled = booster.predict(dte)
        r2, rmse, mae, _, _ = metrics_mwh(region, yte, y_pred_scaled)
        plant_test_rows.append({
            "plant": plant, "region": region,
            "test_r2": r2, "test_rmse": rmse, "test_mae": mae
        })
    except Exception:
        continue

df_plant_test = pd.DataFrame(plant_test_rows)

region_test_raw_rows  = []
region_test_post_rows = []

for region, df_te_region in test.groupby(REGION_COL):
    model_path = region_models.get(region)
    booster_region = load_booster(model_path) if model_path else None
    if booster_region is None or len(df_te_region) == 0: continue

    Xte = df_te_region[feature_cols].to_numpy(np.float32)
    yte = df_te_region[TARGET_NEXT24].to_numpy(np.float32)
    dte = as_dmatrix(Xte)

    y_pred_r_scaled_t = booster_region.predict(dte)
    r2_r_t, rmse_r_t, mae_r_t, y_true_t, y_pred_r_t = metrics_mwh(region, yte, y_pred_r_scaled_t)
    region_test_raw_rows.append({
        "region": region,
        "test_r2": r2_r_t, "test_rmse": rmse_r_t, "test_mae": mae_r_t
    })

    bias_dict = region_hour_bias.get(region, {})
    hours_t   = df_te_region["hour"].to_numpy()
    y_pred_r_cal_t = apply_hour_bias(region, y_pred_r_t, hours_t, bias_dict)

    r2_post_t  = max(r2_score(y_true_t, y_pred_r_cal_t), 0.0)
    rmse_post_t= float(np.sqrt(mean_squared_error(y_true_t, y_pred_r_cal_t)))
    mae_post_t = float(mean_absolute_error(y_true_t, y_pred_r_cal_t))
    region_test_post_rows.append({
        "region": region,
        "r2_post": r2_post_t, "rmse_post": rmse_post_t, "mae_post": mae_post_t
    })

df_region_test_raw  = pd.DataFrame(region_test_raw_rows)
df_region_test_post = pd.DataFrame(region_test_post_rows)

# =========================
# 6) 최종 결과만 출력(가중 평균)
# =========================
def _weighted_avg(values, weights):
    denom = float(weights.sum()) if float(weights.sum()) > 0 else 1.0
    return float((values * weights).sum() / denom)

# Validation 가중 평균
if len(df_plant) > 0:
    w1 = np.array([len(train[train[GROUP_COL]==p]) for p in df_plant["plant"]], dtype=float)
    weighted_r2_1   = _weighted_avg(df_plant["val_r2"].to_numpy(float),   w1)
    weighted_rmse_1 = _weighted_avg(df_plant["val_rmse"].to_numpy(float), w1)
    weighted_mae_1  = _weighted_avg(df_plant["val_mae"].to_numpy(float),  w1)
else:
    weighted_r2_1 = weighted_rmse_1 = weighted_mae_1 = float('nan')

if len(df_region) > 0:
    w2 = np.array([len(train[train[REGION_COL]==r]) for r in df_region["region"]], dtype=float)
    weighted_r2_2   = _weighted_avg(df_region["val_r2"].to_numpy(float),   w2)
    weighted_rmse_2 = _weighted_avg(df_region["val_rmse"].to_numpy(float), w2)
    weighted_mae_2  = _weighted_avg(df_region["val_mae"].to_numpy(float),  w2)
else:
    weighted_r2_2 = weighted_rmse_2 = weighted_mae_2 = float('nan')

if len(df_region_post) > 0:
    w2p = np.array([len(train[train[REGION_COL]==r]) for r in df_region_post["region"]], dtype=float)
    weighted_r2_post   = _weighted_avg(df_region_post["r2_post"].to_numpy(float),   w2p)
    weighted_rmse_post = _weighted_avg(df_region_post["rmse_post"].to_numpy(float), w2p)
    weighted_mae_post  = _weighted_avg(df_region_post["mae_post"].to_numpy(float),  w2p)
else:
    weighted_r2_post = weighted_rmse_post = weighted_mae_post = float('nan')

print("\n===== [VALID] 최종 결과(가중 평균) =====")
print(f"Plant        R²={weighted_r2_1:.4f}  RMSE={weighted_rmse_1:.4f}  MAE={weighted_mae_1:.4f}")
print(f"Region       R²={weighted_r2_2:.4f}  RMSE={weighted_rmse_2:.4f}  MAE={weighted_mae_2:.4f}")
print(f"Region(보정) R²={weighted_r2_post:.4f}  RMSE={weighted_rmse_post:.4f}  MAE={weighted_mae_post:.4f}")

# Test 가중 평균
if len(df_plant_test) > 0:
    w1_t = np.array([len(test[test[GROUP_COL]==p]) for p in df_plant_test["plant"]], dtype=float)
    weighted_r2_1_t   = _weighted_avg(df_plant_test["test_r2"].to_numpy(float),   w1_t)
    weighted_rmse_1_t = _weighted_avg(df_plant_test["test_rmse"].to_numpy(float), w1_t)
    weighted_mae_1_t  = _weighted_avg(df_plant_test["test_mae"].to_numpy(float),  w1_t)
else:
    weighted_r2_1_t = weighted_rmse_1_t = weighted_mae_1_t = float('nan')

if len(df_region_test_raw) > 0:
    w2_t = np.array([len(test[test[REGION_COL]==r]) for r in df_region_test_raw["region"]], dtype=float)
    weighted_r2_2_t   = _weighted_avg(df_region_test_raw["test_r2"].to_numpy(float),   w2_t)
    weighted_rmse_2_t = _weighted_avg(df_region_test_raw["test_rmse"].to_numpy(float), w2_t)
    weighted_mae_2_t  = _weighted_avg(df_region_test_raw["test_mae"].to_numpy(float),  w2_t)
else:
    weighted_r2_2_t = weighted_rmse_2_t = weighted_mae_2_t = float('nan')

if len(df_region_test_post) > 0:
    w2p_t = np.array([len(test[test[REGION_COL]==r]) for r in df_region_test_post["region"]], dtype=float)
    weighted_r2_2p_t   = _weighted_avg(df_region_test_post["r2_post"].to_numpy(float),   w2p_t)
    weighted_rmse_2p_t = _weighted_avg(df_region_test_post["rmse_post"].to_numpy(float), w2p_t)
    weighted_mae_2p_t  = _weighted_avg(df_region_test_post["mae_post"].to_numpy(float),  w2p_t)
else:
    weighted_r2_2p_t = weighted_rmse_2p_t = weighted_mae_2p_t = float('nan')

print("\n===== [TEST] 최종 결과(가중 평균) =====")
print(f"Plant        R²={weighted_r2_1_t:.4f}  RMSE={weighted_rmse_1_t:.4f}  MAE={weighted_mae_1_t:.4f}")
print(f"Region       R²={weighted_r2_2_t:.4f}  RMSE={weighted_rmse_2_t:.4f}  MAE={weighted_mae_2_t:.4f}")
print(f"Region(보정) R²={weighted_r2_2p_t:.4f}  RMSE={weighted_rmse_2p_t:.4f}  MAE={weighted_mae_2p_t:.4f}")

print("\n🏁 완료")
# Out:
# 🔧 CONTEXT_2W=False  FEATURE_MODE=22  DENSE_2W=False  USE_PAST_DELTAS=True
# 🔧 LAGS_CONTEXT size=4  LAGS_FEATURE size=4  LAGS_BUILD size=4
# ✅ feature_cols (22): ['기온(°C)', '강수량(mm)', '풍속(m/s)', '습도(%)', '증기압(hPa)', '일조(hr)', '일사(MJ/m2)', '적설(cm)', '전운량(10분위)', '중하층운량(10분위)', 'hour_sin', 'hour_cos', 'doy_sin', 'doy_cos', 'lag_1', 'lag_3'] ...
#
# 🌱 Plant 1차 학습 시작: 남제주소내 | train size: 78864
# Epoch 1/50 | Val R2=0.3269 | EMA R2=0.3269 ★Best★ | RMSE=0.2473 | MAE=0.1989 | ETA=6.0s
# Epoch 2/50 | Val R2=0.4542 | EMA R2=0.3905 ★Best★ | RMSE=0.2227 | MAE=0.1688 | ETA=6.2s
# Epoch 3/50 | Val R2=0.5152 | EMA R2=0.4529 ★Best★ | RMSE=0.2099 | MAE=0.1529 | ETA=6.5s
# Epoch 4/50 | Val R2=0.5557 | EMA R2=0.5043 ★Best★ | RMSE=0.2009 | MAE=0.1422 | ETA=7.0s
# Epoch 5/50 | Val R2=0.5854 | EMA R2=0.5449 ★Best★ | RMSE=0.1941 | MAE=0.1344 | ETA=7.6s
# Epoch 6/50 | Val R2=0.5973 | EMA R2=0.5711 ★Best★ | RMSE=0.1913 | MAE=0.1307 | ETA=8.0s
# Epoch 7/50 | Val R2=0.6060 | EMA R2=0.5885 ★Best★ | RMSE=0.1892 | MAE=0.1280 | ETA=8.5s
# Epoch 8/50 | Val R2=0.6129 | EMA R2=0.6007 ★Best★ | RMSE=0.1876 | MAE=0.1261 | ETA=9.2s
# Epoch 9/50 | Val R2=0.6179 | EMA R2=0.6093 ★Best★ | RMSE=0.1863 | MAE=0.1248 | ETA=9.4s
# Epoch 10/50 | Val R2=0.6212 | EMA R2=0.6152 ★Best★ | RMSE=0.1855 | MAE=0.1237 | ETA=9.9s
# Epoch 11/50 | Val R2=0.6244 | EMA R2=0.6198 ★Best★ | RMSE=0.1847 | MAE=0.1228 | ETA=10.1s
# Epoch 12/50 | Val R2=0.6277 | EMA R2=0.6238 ★Best★ | RMSE=0.1839 | MAE=0.1219 | ETA=10.2s
# Epoch 13/50 | Val R2=0.6300 | EMA R2=0.6269 ★Best★ | RMSE=0.1834 | MAE=0.1213 | ETA=10.5s
# Epoch 14/50 | Val R2=0.6312 | EMA R2=0.6290 ★Best★ | RMSE=0.1831 | MAE=0.1209 | ETA=10.7s
# Epoch 15/50 | Val R2=0.6317 | EMA R2=0.6304 ★Best★ | RMSE=0.1829 | MAE=0.1207 | ETA=10.8s
# Epoch 16/50 | Val R2=0.6326 | EMA R2=0.6315 ★Best★ | RMSE=0.1827 | MAE=0.1204 | ETA=10.9s
# Epoch 17/50 | Val R2=0.6327 | EMA R2=0.6321 ★Best★ | RMSE=0.1827 | MAE=0.1202 | ETA=11.0s
# Epoch 18/50 | Val R2=0.6333 | EMA R2=0.6327 ★Best★ | RMSE=0.1825 | MAE=0.1200 | ETA=11.0s
# Epoch 19/50 | Val R2=0.6331 | EMA R2=0.6329 ★Best★ | RMSE=0.1826 | MAE=0.1200 | ETA=10.9s
# Epoch 20/50 | Val R2=0.6334 | EMA R2=0.6331 ★Best★ | RMSE=0.1825 | MAE=0.1199 | ETA=10.9s
# Epoch 21/50 | Val R2=0.6334 | EMA R2=0.6333 ★Best★ | RMSE=0.1825 | MAE=0.1198 | ETA=10.8s
# Epoch 22/50 | Val R2=0.6336 | EMA R2=0.6334 ★Best★ | RMSE=0.1825 | MAE=0.1198 | ETA=10.6s
# Epoch 23/50 | Val R2=0.6337 | EMA R2=0.6336 ★Best★ | RMSE=0.1825 | MAE=0.1197 | ETA=10.4s
# Epoch 24/50 | Val R2=0.6333 | EMA R2=0.6334  | RMSE=0.1825 | MAE=0.1198 | ETA=10.2s
# ⏹ EarlyStopping Triggered (best_rounds=1150)
# ✅ Plant 남제주소내 평가 완료 | R2=0.6337 | RMSE=0.1825 | MAE=0.1197
#
# 🌱 Plant 1차 학습 시작: 부산복합자재창고 | train size: 78864
# Epoch 1/50 | Val R2=0.3357 | EMA R2=0.3357 ★Best★ | RMSE=0.2512 | MAE=0.2027 | ETA=5.3s
# Epoch 2/50 | Val R2=0.4296 | EMA R2=0.3826 ★Best★ | RMSE=0.2328 | MAE=0.1783 | ETA=6.2s
# Epoch 3/50 | Val R2=0.4784 | EMA R2=0.4305 ★Best★ | RMSE=0.2226 | MAE=0.1656 | ETA=6.3s
# Epoch 4/50 | Val R2=0.5301 | EMA R2=0.4803 ★Best★ | RMSE=0.2113 | MAE=0.1551 | ETA=6.5s
# Epoch 5/50 | Val R2=0.5582 | EMA R2=0.5193 ★Best★ | RMSE=0.2049 | MAE=0.1492 | ETA=6.6s
# Epoch 6/50 | Val R2=0.5667 | EMA R2=0.5430 ★Best★ | RMSE=0.2029 | MAE=0.1473 | ETA=6.7s
# Epoch 7/50 | Val R2=0.5673 | EMA R2=0.5551 ★Best★ | RMSE=0.2028 | MAE=0.1472 | ETA=6.6s
# Epoch 8/50 | Val R2=0.5693 | EMA R2=0.5622 ★Best★ | RMSE=0.2023 | MAE=0.1468 | ETA=6.6s
# Epoch 9/50 | Val R2=0.5700 | EMA R2=0.5661 ★Best★ | RMSE=0.2021 | MAE=0.1466 | ETA=6.5s
# Epoch 10/50 | Val R2=0.5701 | EMA R2=0.5681 ★Best★ | RMSE=0.2021 | MAE=0.1466 | ETA=6.6s
# Epoch 11/50 | Val R2=0.5703 | EMA R2=0.5692 ★Best★ | RMSE=0.2021 | MAE=0.1466 | ETA=6.5s
# Epoch 12/50 | Val R2=0.5703 | EMA R2=0.5697 ★Best★ | RMSE=0.2021 | MAE=0.1466 | ETA=6.4s
# Epoch 13/50 | Val R2=0.5709 | EMA R2=0.5703 ★Best★ | RMSE=0.2019 | MAE=0.1465 | ETA=6.3s
# Epoch 14/50 | Val R2=0.5708 | EMA R2=0.5706 ★Best★ | RMSE=0.2019 | MAE=0.1465 | ETA=6.1s
# Epoch 15/50 | Val R2=0.5709 | EMA R2=0.5707 ★Best★ | RMSE=0.2019 | MAE=0.1465 | ETA=6.0s
# Epoch 16/50 | Val R2=0.5710 | EMA R2=0.5709 ★Best★ | RMSE=0.2019 | MAE=0.1465 | ETA=6.0s
# Epoch 17/50 | Val R2=0.5714 | EMA R2=0.5711 ★Best★ | RMSE=0.2018 | MAE=0.1464 | ETA=5.8s
# Epoch 18/50 | Val R2=0.5713 | EMA R2=0.5712  | RMSE=0.2018 | MAE=0.1464 | ETA=5.7s
# ⏹ EarlyStopping Triggered (best_rounds=850)
# ✅ Plant 부산복합자재창고 평가 완료 | R2=0.5714 | RMSE=0.2018 | MAE=0.1464
#
# 🌱 Plant 1차 학습 시작: 부산본부 | train size: 78864
# Epoch 1/50 | Val R2=0.0000 | EMA R2=0.0000 ★Best★ | RMSE=1.0965 | MAE=0.8957 | ETA=6.3s
# Epoch 2/50 | Val R2=0.0460 | EMA R2=0.0230 ★Best★ | RMSE=0.9663 | MAE=0.7169 | ETA=5.9s
# Epoch 3/50 | Val R2=0.1453 | EMA R2=0.0842 ★Best★ | RMSE=0.9146 | MAE=0.6497 | ETA=6.0s
# Epoch 4/50 | Val R2=0.2200 | EMA R2=0.1521 ★Best★ | RMSE=0.8737 | MAE=0.6064 | ETA=6.4s
# Epoch 5/50 | Val R2=0.2614 | EMA R2=0.2068 ★Best★ | RMSE=0.8502 | MAE=0.5830 | ETA=7.0s
# Epoch 6/50 | Val R2=0.2815 | EMA R2=0.2441 ★Best★ | RMSE=0.8386 | MAE=0.5724 | ETA=7.4s
# Epoch 7/50 | Val R2=0.2949 | EMA R2=0.2695 ★Best★ | RMSE=0.8308 | MAE=0.5653 | ETA=7.7s
# Epoch 8/50 | Val R2=0.3056 | EMA R2=0.2876 ★Best★ | RMSE=0.8244 | MAE=0.5597 | ETA=8.7s
# Epoch 9/50 | Val R2=0.3148 | EMA R2=0.3012 ★Best★ | RMSE=0.8190 | MAE=0.5548 | ETA=9.4s
# Epoch 10/50 | Val R2=0.3215 | EMA R2=0.3113 ★Best★ | RMSE=0.8149 | MAE=0.5508 | ETA=9.7s
# Epoch 11/50 | Val R2=0.3235 | EMA R2=0.3174 ★Best★ | RMSE=0.8137 | MAE=0.5496 | ETA=9.9s
# Epoch 12/50 | Val R2=0.3253 | EMA R2=0.3213 ★Best★ | RMSE=0.8127 | MAE=0.5487 | ETA=10.0s
# Epoch 13/50 | Val R2=0.3270 | EMA R2=0.3242 ★Best★ | RMSE=0.8116 | MAE=0.5478 | ETA=9.9s
# Epoch 14/50 | Val R2=0.3278 | EMA R2=0.3260 ★Best★ | RMSE=0.8111 | MAE=0.5473 | ETA=9.8s
# Epoch 15/50 | Val R2=0.3286 | EMA R2=0.3273 ★Best★ | RMSE=0.8107 | MAE=0.5469 | ETA=9.8s
# Epoch 16/50 | Val R2=0.3290 | EMA R2=0.3281 ★Best★ | RMSE=0.8104 | MAE=0.5468 | ETA=9.7s
# Epoch 17/50 | Val R2=0.3293 | EMA R2=0.3287 ★Best★ | RMSE=0.8102 | MAE=0.5466 | ETA=9.6s
# Epoch 18/50 | Val R2=0.3296 | EMA R2=0.3291 ★Best★ | RMSE=0.8100 | MAE=0.5464 | ETA=9.4s
# Epoch 19/50 | Val R2=0.3302 | EMA R2=0.3297 ★Best★ | RMSE=0.8097 | MAE=0.5462 | ETA=9.3s
# Epoch 20/50 | Val R2=0.3301 | EMA R2=0.3299 ★Best★ | RMSE=0.8097 | MAE=0.5462 | ETA=9.1s
# Epoch 21/50 | Val R2=0.3303 | EMA R2=0.3301 ★Best★ | RMSE=0.8096 | MAE=0.5461 | ETA=8.9s
# Epoch 22/50 | Val R2=0.3310 | EMA R2=0.3306 ★Best★ | RMSE=0.8092 | MAE=0.5458 | ETA=8.8s
# Epoch 23/50 | Val R2=0.3313 | EMA R2=0.3309 ★Best★ | RMSE=0.8090 | MAE=0.5456 | ETA=8.6s
# Epoch 24/50 | Val R2=0.3313 | EMA R2=0.3311 ★Best★ | RMSE=0.8090 | MAE=0.5456 | ETA=8.5s
# Epoch 25/50 | Val R2=0.3319 | EMA R2=0.3315 ★Best★ | RMSE=0.8087 | MAE=0.5453 | ETA=8.3s
# Epoch 26/50 | Val R2=0.3321 | EMA R2=0.3318 ★Best★ | RMSE=0.8085 | MAE=0.5452 | ETA=8.0s
# Epoch 27/50 | Val R2=0.3323 | EMA R2=0.3320 ★Best★ | RMSE=0.8084 | MAE=0.5451 | ETA=7.8s
# Epoch 28/50 | Val R2=0.3324 | EMA R2=0.3322 ★Best★ | RMSE=0.8084 | MAE=0.5450 | ETA=7.6s
# Epoch 29/50 | Val R2=0.3327 | EMA R2=0.3325 ★Best★ | RMSE=0.8081 | MAE=0.5449 | ETA=7.3s
# Epoch 30/50 | Val R2=0.3327 | EMA R2=0.3326 ★Best★ | RMSE=0.8082 | MAE=0.5448 | ETA=7.0s
# Epoch 31/50 | Val R2=0.3329 | EMA R2=0.3327 ★Best★ | RMSE=0.8080 | MAE=0.5447 | ETA=6.7s
# Epoch 32/50 | Val R2=0.3333 | EMA R2=0.3330 ★Best★ | RMSE=0.8078 | MAE=0.5445 | ETA=6.5s
# Epoch 33/50 | Val R2=0.3339 | EMA R2=0.3335 ★Best★ | RMSE=0.8074 | MAE=0.5442 | ETA=6.2s
# Epoch 34/50 | Val R2=0.3339 | EMA R2=0.3337 ★Best★ | RMSE=0.8074 | MAE=0.5443 | ETA=5.9s
# Epoch 35/50 | Val R2=0.3340 | EMA R2=0.3338 ★Best★ | RMSE=0.8074 | MAE=0.5442 | ETA=5.6s
# Epoch 36/50 | Val R2=0.3341 | EMA R2=0.3340 ★Best★ | RMSE=0.8073 | MAE=0.5441 | ETA=5.2s
# Epoch 37/50 | Val R2=0.3343 | EMA R2=0.3341 ★Best★ | RMSE=0.8072 | MAE=0.5440 | ETA=4.9s
# Epoch 38/50 | Val R2=0.3346 | EMA R2=0.3344 ★Best★ | RMSE=0.8070 | MAE=0.5439 | ETA=4.6s
# Epoch 39/50 | Val R2=0.3345 | EMA R2=0.3344  | RMSE=0.8071 | MAE=0.5440 | ETA=4.2s
# ⏹ EarlyStopping Triggered (best_rounds=1900)
# ✅ Plant 부산본부 평가 완료 | R2=0.3346 | RMSE=0.8070 | MAE=0.5439
#
# 🌱 Plant 1차 학습 시작: 부산수처리장 | train size: 35040
# Epoch 1/50 | Val R2=0.3576 | EMA R2=0.3576 ★Best★ | RMSE=0.1702 | MAE=0.1399 | ETA=3.2s
# Epoch 2/50 | Val R2=0.4709 | EMA R2=0.4143 ★Best★ | RMSE=0.1545 | MAE=0.1202 | ETA=3.5s
# Epoch 3/50 | Val R2=0.5167 | EMA R2=0.4655 ★Best★ | RMSE=0.1476 | MAE=0.1106 | ETA=3.6s
# Epoch 4/50 | Val R2=0.5466 | EMA R2=0.5060 ★Best★ | RMSE=0.1430 | MAE=0.1045 | ETA=3.7s
# Epoch 5/50 | Val R2=0.5504 | EMA R2=0.5282 ★Best★ | RMSE=0.1424 | MAE=0.1038 | ETA=3.8s
# Epoch 6/50 | Val R2=0.5520 | EMA R2=0.5401 ★Best★ | RMSE=0.1421 | MAE=0.1034 | ETA=3.8s
# Epoch 7/50 | Val R2=0.5522 | EMA R2=0.5462 ★Best★ | RMSE=0.1421 | MAE=0.1033 | ETA=3.8s
# Epoch 8/50 | Val R2=0.5527 | EMA R2=0.5494 ★Best★ | RMSE=0.1420 | MAE=0.1032 | ETA=3.7s
# Epoch 9/50 | Val R2=0.5530 | EMA R2=0.5512 ★Best★ | RMSE=0.1420 | MAE=0.1032 | ETA=3.7s
# Epoch 10/50 | Val R2=0.5530 | EMA R2=0.5521 ★Best★ | RMSE=0.1420 | MAE=0.1032 | ETA=3.7s
# Epoch 11/50 | Val R2=0.5529 | EMA R2=0.5525 ★Best★ | RMSE=0.1420 | MAE=0.1032 | ETA=3.6s
# Epoch 12/50 | Val R2=0.5530 | EMA R2=0.5528 ★Best★ | RMSE=0.1420 | MAE=0.1032 | ETA=3.6s
# Epoch 13/50 | Val R2=0.5530 | EMA R2=0.5529 ★Best★ | RMSE=0.1420 | MAE=0.1032 | ETA=3.6s
# Epoch 14/50 | Val R2=0.5529 | EMA R2=0.5529  | RMSE=0.1420 | MAE=0.1032 | ETA=3.5s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 부산수처리장 평가 완료 | R2=0.5530 | RMSE=0.1420 | MAE=0.1032
#
# 🌱 Plant 1차 학습 시작: 부산신항 | train size: 78864
# Epoch 1/50 | Val R2=0.4060 | EMA R2=0.4060 ★Best★ | RMSE=0.1051 | MAE=0.0810 | ETA=6.2s
# Epoch 2/50 | Val R2=0.5308 | EMA R2=0.4684 ★Best★ | RMSE=0.0934 | MAE=0.0691 | ETA=6.2s
# Epoch 3/50 | Val R2=0.5786 | EMA R2=0.5235 ★Best★ | RMSE=0.0885 | MAE=0.0645 | ETA=6.1s
# Epoch 4/50 | Val R2=0.6006 | EMA R2=0.5620 ★Best★ | RMSE=0.0862 | MAE=0.0622 | ETA=6.1s
# Epoch 5/50 | Val R2=0.6092 | EMA R2=0.5856 ★Best★ | RMSE=0.0853 | MAE=0.0613 | ETA=6.0s
# Epoch 6/50 | Val R2=0.6093 | EMA R2=0.5974 ★Best★ | RMSE=0.0853 | MAE=0.0613 | ETA=5.9s
# Epoch 7/50 | Val R2=0.6093 | EMA R2=0.6034 ★Best★ | RMSE=0.0852 | MAE=0.0613 | ETA=5.7s
# Epoch 8/50 | Val R2=0.6097 | EMA R2=0.6066 ★Best★ | RMSE=0.0852 | MAE=0.0612 | ETA=5.6s
# Epoch 9/50 | Val R2=0.6098 | EMA R2=0.6082 ★Best★ | RMSE=0.0852 | MAE=0.0613 | ETA=5.7s
# Epoch 10/50 | Val R2=0.6099 | EMA R2=0.6090 ★Best★ | RMSE=0.0852 | MAE=0.0612 | ETA=5.5s
# Epoch 11/50 | Val R2=0.6103 | EMA R2=0.6097 ★Best★ | RMSE=0.0851 | MAE=0.0612 | ETA=5.4s
# Epoch 12/50 | Val R2=0.6103 | EMA R2=0.6100 ★Best★ | RMSE=0.0851 | MAE=0.0612 | ETA=5.4s
# Epoch 13/50 | Val R2=0.6103 | EMA R2=0.6101 ★Best★ | RMSE=0.0851 | MAE=0.0612 | ETA=5.3s
# Epoch 14/50 | Val R2=0.6103 | EMA R2=0.6102  | RMSE=0.0851 | MAE=0.0612 | ETA=5.2s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 부산신항 평가 완료 | R2=0.6103 | RMSE=0.0851 | MAE=0.0612
#
# 🌱 Plant 1차 학습 시작: 부산운동장 | train size: 35040
# Epoch 1/50 | Val R2=0.4492 | EMA R2=0.4492 ★Best★ | RMSE=1.6637 | MAE=1.3891 | ETA=3.5s
# Epoch 2/50 | Val R2=0.5638 | EMA R2=0.5065 ★Best★ | RMSE=1.4806 | MAE=1.1589 | ETA=3.9s
# Epoch 3/50 | Val R2=0.6091 | EMA R2=0.5578 ★Best★ | RMSE=1.4015 | MAE=1.0469 | ETA=4.2s
# Epoch 4/50 | Val R2=0.6370 | EMA R2=0.5974 ★Best★ | RMSE=1.3506 | MAE=0.9820 | ETA=5.0s
# Epoch 5/50 | Val R2=0.6549 | EMA R2=0.6262 ★Best★ | RMSE=1.3168 | MAE=0.9436 | ETA=5.3s
# Epoch 6/50 | Val R2=0.6600 | EMA R2=0.6431 ★Best★ | RMSE=1.3071 | MAE=0.9312 | ETA=5.5s
# Epoch 7/50 | Val R2=0.6637 | EMA R2=0.6534 ★Best★ | RMSE=1.2999 | MAE=0.9219 | ETA=5.8s
# Epoch 8/50 | Val R2=0.6676 | EMA R2=0.6605 ★Best★ | RMSE=1.2924 | MAE=0.9132 | ETA=6.1s
# Epoch 9/50 | Val R2=0.6700 | EMA R2=0.6653 ★Best★ | RMSE=1.2877 | MAE=0.9068 | ETA=6.3s
# Epoch 10/50 | Val R2=0.6707 | EMA R2=0.6680 ★Best★ | RMSE=1.2864 | MAE=0.9045 | ETA=6.4s
# Epoch 11/50 | Val R2=0.6718 | EMA R2=0.6699 ★Best★ | RMSE=1.2843 | MAE=0.9021 | ETA=6.5s
# Epoch 12/50 | Val R2=0.6717 | EMA R2=0.6708 ★Best★ | RMSE=1.2844 | MAE=0.9018 | ETA=6.6s
# Epoch 13/50 | Val R2=0.6721 | EMA R2=0.6714 ★Best★ | RMSE=1.2837 | MAE=0.9010 | ETA=6.7s
# Epoch 14/50 | Val R2=0.6722 | EMA R2=0.6718 ★Best★ | RMSE=1.2835 | MAE=0.9007 | ETA=6.7s
# Epoch 15/50 | Val R2=0.6725 | EMA R2=0.6722 ★Best★ | RMSE=1.2828 | MAE=0.9000 | ETA=6.7s
# Epoch 16/50 | Val R2=0.6730 | EMA R2=0.6726 ★Best★ | RMSE=1.2819 | MAE=0.8991 | ETA=6.6s
# Epoch 17/50 | Val R2=0.6733 | EMA R2=0.6730 ★Best★ | RMSE=1.2813 | MAE=0.8985 | ETA=6.6s
# Epoch 18/50 | Val R2=0.6734 | EMA R2=0.6732 ★Best★ | RMSE=1.2810 | MAE=0.8983 | ETA=6.5s
# Epoch 19/50 | Val R2=0.6733 | EMA R2=0.6733  | RMSE=1.2813 | MAE=0.8985 | ETA=6.4s
# ⏹ EarlyStopping Triggered (best_rounds=900)
# ✅ Plant 부산운동장 평가 완료 | R2=0.6734 | RMSE=1.2810 | MAE=0.8983
#
# 🌱 Plant 1차 학습 시작: 삼척소내 | train size: 35040
# Epoch 1/50 | Val R2=0.1643 | EMA R2=0.1643 ★Best★ | RMSE=9.4870 | MAE=8.0750 | ETA=3.4s
# Epoch 2/50 | Val R2=0.4801 | EMA R2=0.3222 ★Best★ | RMSE=7.4826 | MAE=6.0875 | ETA=3.8s
# Epoch 3/50 | Val R2=0.5788 | EMA R2=0.4505 ★Best★ | RMSE=6.7349 | MAE=5.2286 | ETA=4.2s
# Epoch 4/50 | Val R2=0.6189 | EMA R2=0.5347 ★Best★ | RMSE=6.4066 | MAE=4.8116 | ETA=4.5s
# Epoch 5/50 | Val R2=0.6377 | EMA R2=0.5862 ★Best★ | RMSE=6.2463 | MAE=4.6140 | ETA=4.9s
# Epoch 6/50 | Val R2=0.6451 | EMA R2=0.6156 ★Best★ | RMSE=6.1826 | MAE=4.5268 | ETA=5.2s
# Epoch 7/50 | Val R2=0.6498 | EMA R2=0.6327 ★Best★ | RMSE=6.1411 | MAE=4.4812 | ETA=5.4s
# Epoch 8/50 | Val R2=0.6521 | EMA R2=0.6424 ★Best★ | RMSE=6.1214 | MAE=4.4562 | ETA=5.7s
# Epoch 9/50 | Val R2=0.6535 | EMA R2=0.6479 ★Best★ | RMSE=6.1090 | MAE=4.4442 | ETA=5.8s
# Epoch 10/50 | Val R2=0.6534 | EMA R2=0.6507 ★Best★ | RMSE=6.1094 | MAE=4.4438 | ETA=5.9s
# Epoch 11/50 | Val R2=0.6537 | EMA R2=0.6522 ★Best★ | RMSE=6.1066 | MAE=4.4410 | ETA=6.0s
# Epoch 12/50 | Val R2=0.6530 | EMA R2=0.6526 ★Best★ | RMSE=6.1131 | MAE=4.4464 | ETA=6.0s
# Epoch 13/50 | Val R2=0.6531 | EMA R2=0.6528 ★Best★ | RMSE=6.1124 | MAE=4.4475 | ETA=6.1s
# Epoch 14/50 | Val R2=0.6531 | EMA R2=0.6530 ★Best★ | RMSE=6.1120 | MAE=4.4455 | ETA=6.1s
# Epoch 15/50 | Val R2=0.6534 | EMA R2=0.6532 ★Best★ | RMSE=6.1092 | MAE=4.4415 | ETA=6.0s
# Epoch 16/50 | Val R2=0.6536 | EMA R2=0.6534 ★Best★ | RMSE=6.1078 | MAE=4.4401 | ETA=6.0s
# Epoch 17/50 | Val R2=0.6536 | EMA R2=0.6535 ★Best★ | RMSE=6.1076 | MAE=4.4411 | ETA=5.9s
# Epoch 18/50 | Val R2=0.6537 | EMA R2=0.6536 ★Best★ | RMSE=6.1066 | MAE=4.4402 | ETA=5.9s
# Epoch 19/50 | Val R2=0.6538 | EMA R2=0.6537  | RMSE=6.1064 | MAE=4.4394 | ETA=5.7s
# ⏹ EarlyStopping Triggered (best_rounds=900)
# ✅ Plant 삼척소내 평가 완료 | R2=0.6537 | RMSE=6.1066 | MAE=4.4402
#
# 🌱 Plant 1차 학습 시작: 송당리 | train size: 18216
# Epoch 1/50 | Val R2=0.3641 | EMA R2=0.3641 ★Best★ | RMSE=1.4890 | MAE=1.2211 | ETA=2.9s
# Epoch 2/50 | Val R2=0.4860 | EMA R2=0.4250 ★Best★ | RMSE=1.3386 | MAE=1.0470 | ETA=3.3s
# Epoch 3/50 | Val R2=0.5288 | EMA R2=0.4769 ★Best★ | RMSE=1.2817 | MAE=0.9665 | ETA=3.6s
# Epoch 4/50 | Val R2=0.5459 | EMA R2=0.5114 ★Best★ | RMSE=1.2582 | MAE=0.9285 | ETA=3.9s
# Epoch 5/50 | Val R2=0.5547 | EMA R2=0.5331 ★Best★ | RMSE=1.2459 | MAE=0.9069 | ETA=4.2s
# Epoch 6/50 | Val R2=0.5558 | EMA R2=0.5444 ★Best★ | RMSE=1.2444 | MAE=0.9009 | ETA=4.5s
# Epoch 7/50 | Val R2=0.5566 | EMA R2=0.5505 ★Best★ | RMSE=1.2433 | MAE=0.8963 | ETA=4.8s
# Epoch 8/50 | Val R2=0.5569 | EMA R2=0.5537 ★Best★ | RMSE=1.2429 | MAE=0.8937 | ETA=5.0s
# Epoch 9/50 | Val R2=0.5585 | EMA R2=0.5561 ★Best★ | RMSE=1.2407 | MAE=0.8907 | ETA=5.2s
# Epoch 10/50 | Val R2=0.5588 | EMA R2=0.5575 ★Best★ | RMSE=1.2402 | MAE=0.8897 | ETA=5.3s
# Epoch 11/50 | Val R2=0.5589 | EMA R2=0.5582 ★Best★ | RMSE=1.2401 | MAE=0.8893 | ETA=5.4s
# Epoch 12/50 | Val R2=0.5591 | EMA R2=0.5586 ★Best★ | RMSE=1.2398 | MAE=0.8884 | ETA=5.4s
# Epoch 13/50 | Val R2=0.5586 | EMA R2=0.5586  | RMSE=1.2404 | MAE=0.8884 | ETA=5.4s
# ⏹ EarlyStopping Triggered (best_rounds=600)
# ✅ Plant 송당리 평가 완료 | R2=0.5591 | RMSE=1.2398 | MAE=0.8884
#
# 🌱 Plant 1차 학습 시작: 신인천 주차장 | train size: 17688
# Epoch 1/50 | Val R2=0.5201 | EMA R2=0.5201 ★Best★ | RMSE=0.6191 | MAE=0.5118 | ETA=2.8s
# Epoch 2/50 | Val R2=0.6334 | EMA R2=0.5768 ★Best★ | RMSE=0.5412 | MAE=0.4271 | ETA=3.2s
# Epoch 3/50 | Val R2=0.6679 | EMA R2=0.6223 ★Best★ | RMSE=0.5151 | MAE=0.3912 | ETA=3.8s
# Epoch 4/50 | Val R2=0.6835 | EMA R2=0.6529 ★Best★ | RMSE=0.5028 | MAE=0.3742 | ETA=4.3s
# Epoch 5/50 | Val R2=0.6929 | EMA R2=0.6729 ★Best★ | RMSE=0.4953 | MAE=0.3649 | ETA=4.4s
# Epoch 6/50 | Val R2=0.6948 | EMA R2=0.6839 ★Best★ | RMSE=0.4937 | MAE=0.3627 | ETA=4.5s
# Epoch 7/50 | Val R2=0.6951 | EMA R2=0.6895 ★Best★ | RMSE=0.4935 | MAE=0.3622 | ETA=4.5s
# Epoch 8/50 | Val R2=0.6959 | EMA R2=0.6927 ★Best★ | RMSE=0.4928 | MAE=0.3615 | ETA=4.5s
# Epoch 9/50 | Val R2=0.6959 | EMA R2=0.6943 ★Best★ | RMSE=0.4929 | MAE=0.3615 | ETA=4.5s
# Epoch 10/50 | Val R2=0.6959 | EMA R2=0.6951 ★Best★ | RMSE=0.4928 | MAE=0.3614 | ETA=4.5s
# Epoch 11/50 | Val R2=0.6961 | EMA R2=0.6956 ★Best★ | RMSE=0.4927 | MAE=0.3612 | ETA=4.4s
# Epoch 12/50 | Val R2=0.6961 | EMA R2=0.6959 ★Best★ | RMSE=0.4927 | MAE=0.3611 | ETA=4.4s
# Epoch 13/50 | Val R2=0.6960 | EMA R2=0.6959  | RMSE=0.4927 | MAE=0.3612 | ETA=4.3s
# ⏹ EarlyStopping Triggered (best_rounds=600)
# ✅ Plant 신인천 주차장 평가 완료 | R2=0.6961 | RMSE=0.4927 | MAE=0.3611
#
# 🌱 Plant 1차 학습 시작: 신인천전망대 | train size: 35040
# Epoch 1/50 | Val R2=0.4450 | EMA R2=0.4450 ★Best★ | RMSE=1.6683 | MAE=1.3641 | ETA=4.0s
# Epoch 2/50 | Val R2=0.5286 | EMA R2=0.4868 ★Best★ | RMSE=1.5376 | MAE=1.2197 | ETA=4.5s
# Epoch 3/50 | Val R2=0.5548 | EMA R2=0.5208 ★Best★ | RMSE=1.4942 | MAE=1.1641 | ETA=4.8s
# Epoch 4/50 | Val R2=0.5615 | EMA R2=0.5412 ★Best★ | RMSE=1.4828 | MAE=1.1441 | ETA=5.0s
# Epoch 5/50 | Val R2=0.5673 | EMA R2=0.5542 ★Best★ | RMSE=1.4730 | MAE=1.1303 | ETA=5.3s
# Epoch 6/50 | Val R2=0.5691 | EMA R2=0.5617 ★Best★ | RMSE=1.4699 | MAE=1.1249 | ETA=5.6s
# Epoch 7/50 | Val R2=0.5701 | EMA R2=0.5659 ★Best★ | RMSE=1.4682 | MAE=1.1221 | ETA=5.9s
# Epoch 8/50 | Val R2=0.5728 | EMA R2=0.5694 ★Best★ | RMSE=1.4636 | MAE=1.1173 | ETA=6.3s
# Epoch 9/50 | Val R2=0.5744 | EMA R2=0.5719 ★Best★ | RMSE=1.4609 | MAE=1.1148 | ETA=6.5s
# Epoch 10/50 | Val R2=0.5745 | EMA R2=0.5732 ★Best★ | RMSE=1.4607 | MAE=1.1146 | ETA=6.8s
# Epoch 11/50 | Val R2=0.5751 | EMA R2=0.5741 ★Best★ | RMSE=1.4598 | MAE=1.1144 | ETA=7.0s
# Epoch 12/50 | Val R2=0.5751 | EMA R2=0.5746 ★Best★ | RMSE=1.4596 | MAE=1.1145 | ETA=7.2s
# Epoch 13/50 | Val R2=0.5753 | EMA R2=0.5750 ★Best★ | RMSE=1.4593 | MAE=1.1140 | ETA=7.3s
# Epoch 14/50 | Val R2=0.5751 | EMA R2=0.5750  | RMSE=1.4598 | MAE=1.1143 | ETA=7.2s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 신인천전망대 평가 완료 | R2=0.5753 | RMSE=1.4593 | MAE=1.1140
#
# 🌱 Plant 1차 학습 시작: 신인천해수구취수구 | train size: 26352
# Epoch 1/50 | Val R2=0.5375 | EMA R2=0.5375 ★Best★ | RMSE=0.8968 | MAE=0.7184 | ETA=3.1s
# Epoch 2/50 | Val R2=0.6552 | EMA R2=0.5963 ★Best★ | RMSE=0.7742 | MAE=0.5773 | ETA=3.5s
# Epoch 3/50 | Val R2=0.6929 | EMA R2=0.6446 ★Best★ | RMSE=0.7307 | MAE=0.5225 | ETA=3.9s
# Epoch 4/50 | Val R2=0.7084 | EMA R2=0.6765 ★Best★ | RMSE=0.7120 | MAE=0.5007 | ETA=4.2s
# Epoch 5/50 | Val R2=0.7184 | EMA R2=0.6975 ★Best★ | RMSE=0.6996 | MAE=0.4889 | ETA=4.4s
# Epoch 6/50 | Val R2=0.7216 | EMA R2=0.7095 ★Best★ | RMSE=0.6957 | MAE=0.4842 | ETA=4.7s
# Epoch 7/50 | Val R2=0.7233 | EMA R2=0.7164 ★Best★ | RMSE=0.6936 | MAE=0.4824 | ETA=4.9s
# Epoch 8/50 | Val R2=0.7235 | EMA R2=0.7199 ★Best★ | RMSE=0.6933 | MAE=0.4821 | ETA=5.0s
# Epoch 9/50 | Val R2=0.7240 | EMA R2=0.7220 ★Best★ | RMSE=0.6926 | MAE=0.4814 | ETA=5.1s
# Epoch 10/50 | Val R2=0.7246 | EMA R2=0.7233 ★Best★ | RMSE=0.6920 | MAE=0.4807 | ETA=5.1s
# Epoch 11/50 | Val R2=0.7244 | EMA R2=0.7238 ★Best★ | RMSE=0.6922 | MAE=0.4807 | ETA=5.1s
# Epoch 12/50 | Val R2=0.7247 | EMA R2=0.7243 ★Best★ | RMSE=0.6919 | MAE=0.4803 | ETA=5.2s
# Epoch 13/50 | Val R2=0.7249 | EMA R2=0.7246 ★Best★ | RMSE=0.6915 | MAE=0.4799 | ETA=5.2s
# Epoch 14/50 | Val R2=0.7250 | EMA R2=0.7248 ★Best★ | RMSE=0.6915 | MAE=0.4799 | ETA=5.1s
# Epoch 15/50 | Val R2=0.7251 | EMA R2=0.7249 ★Best★ | RMSE=0.6913 | MAE=0.4797 | ETA=5.1s
# Epoch 16/50 | Val R2=0.7250 | EMA R2=0.7250  | RMSE=0.6915 | MAE=0.4799 | ETA=5.0s
# ⏹ EarlyStopping Triggered (best_rounds=750)
# ✅ Plant 신인천해수구취수구 평가 완료 | R2=0.7251 | RMSE=0.6913 | MAE=0.4797
#
# 🌱 Plant 1차 학습 시작: 영월철도부지 | train size: 32880
# Epoch 1/50 | Val R2=0.4472 | EMA R2=0.4472 ★Best★ | RMSE=1.3855 | MAE=1.1484 | ETA=3.4s
# Epoch 2/50 | Val R2=0.6010 | EMA R2=0.5241 ★Best★ | RMSE=1.1771 | MAE=0.9369 | ETA=3.8s
# Epoch 3/50 | Val R2=0.6539 | EMA R2=0.5890 ★Best★ | RMSE=1.0962 | MAE=0.8435 | ETA=4.2s
# Epoch 4/50 | Val R2=0.6747 | EMA R2=0.6319 ★Best★ | RMSE=1.0628 | MAE=0.8012 | ETA=4.7s
# Epoch 5/50 | Val R2=0.6848 | EMA R2=0.6584 ★Best★ | RMSE=1.0461 | MAE=0.7796 | ETA=5.0s
# Epoch 6/50 | Val R2=0.6892 | EMA R2=0.6738 ★Best★ | RMSE=1.0388 | MAE=0.7693 | ETA=5.4s
# Epoch 7/50 | Val R2=0.6915 | EMA R2=0.6827 ★Best★ | RMSE=1.0350 | MAE=0.7623 | ETA=5.7s
# Epoch 8/50 | Val R2=0.6928 | EMA R2=0.6877 ★Best★ | RMSE=1.0328 | MAE=0.7586 | ETA=6.1s
# Epoch 9/50 | Val R2=0.6939 | EMA R2=0.6908 ★Best★ | RMSE=1.0310 | MAE=0.7557 | ETA=6.3s
# Epoch 10/50 | Val R2=0.6940 | EMA R2=0.6924 ★Best★ | RMSE=1.0308 | MAE=0.7545 | ETA=6.5s
# Epoch 11/50 | Val R2=0.6942 | EMA R2=0.6933 ★Best★ | RMSE=1.0305 | MAE=0.7535 | ETA=6.7s
# Epoch 12/50 | Val R2=0.6942 | EMA R2=0.6938 ★Best★ | RMSE=1.0304 | MAE=0.7530 | ETA=6.8s
# Epoch 13/50 | Val R2=0.6943 | EMA R2=0.6940 ★Best★ | RMSE=1.0304 | MAE=0.7529 | ETA=6.9s
# Epoch 14/50 | Val R2=0.6940 | EMA R2=0.6940  | RMSE=1.0308 | MAE=0.7529 | ETA=6.8s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 영월철도부지 평가 완료 | R2=0.6943 | RMSE=1.0304 | MAE=0.7529
#
# 🌱 Plant 1차 학습 시작: 하동공설운동장 | train size: 78864
# Epoch 1/50 | Val R2=0.5377 | EMA R2=0.5377 ★Best★ | RMSE=0.3084 | MAE=0.2469 | ETA=5.2s
# Epoch 2/50 | Val R2=0.6496 | EMA R2=0.5936 ★Best★ | RMSE=0.2685 | MAE=0.2032 | ETA=5.3s
# Epoch 3/50 | Val R2=0.6839 | EMA R2=0.6388 ★Best★ | RMSE=0.2550 | MAE=0.1855 | ETA=5.5s
# Epoch 4/50 | Val R2=0.6983 | EMA R2=0.6686 ★Best★ | RMSE=0.2491 | MAE=0.1785 | ETA=5.8s
# Epoch 5/50 | Val R2=0.7050 | EMA R2=0.6868 ★Best★ | RMSE=0.2463 | MAE=0.1756 | ETA=5.9s
# Epoch 6/50 | Val R2=0.7067 | EMA R2=0.6967 ★Best★ | RMSE=0.2456 | MAE=0.1749 | ETA=6.0s
# Epoch 7/50 | Val R2=0.7068 | EMA R2=0.7017 ★Best★ | RMSE=0.2456 | MAE=0.1749 | ETA=6.0s
# Epoch 8/50 | Val R2=0.7071 | EMA R2=0.7044 ★Best★ | RMSE=0.2454 | MAE=0.1747 | ETA=6.0s
# Epoch 9/50 | Val R2=0.7072 | EMA R2=0.7058 ★Best★ | RMSE=0.2454 | MAE=0.1747 | ETA=5.9s
# Epoch 10/50 | Val R2=0.7072 | EMA R2=0.7065 ★Best★ | RMSE=0.2454 | MAE=0.1747 | ETA=5.8s
# Epoch 11/50 | Val R2=0.7072 | EMA R2=0.7069 ★Best★ | RMSE=0.2454 | MAE=0.1748 | ETA=5.8s
# Epoch 12/50 | Val R2=0.7072 | EMA R2=0.7070 ★Best★ | RMSE=0.2454 | MAE=0.1747 | ETA=5.7s
# Epoch 13/50 | Val R2=0.7073 | EMA R2=0.7072 ★Best★ | RMSE=0.2454 | MAE=0.1747 | ETA=5.6s
# Epoch 14/50 | Val R2=0.7074 | EMA R2=0.7073  | RMSE=0.2453 | MAE=0.1747 | ETA=5.5s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 하동공설운동장 평가 완료 | R2=0.7073 | RMSE=0.2454 | MAE=0.1747
#
# 🌱 Plant 1차 학습 시작: 하동변전소 | train size: 78864
# Epoch 1/50 | Val R2=0.4437 | EMA R2=0.4437 ★Best★ | RMSE=0.0544 | MAE=0.0425 | ETA=5.7s
# Epoch 2/50 | Val R2=0.5395 | EMA R2=0.4916 ★Best★ | RMSE=0.0495 | MAE=0.0375 | ETA=4.7s
# Epoch 3/50 | Val R2=0.5802 | EMA R2=0.5359 ★Best★ | RMSE=0.0473 | MAE=0.0351 | ETA=4.3s
# Epoch 4/50 | Val R2=0.5827 | EMA R2=0.5593 ★Best★ | RMSE=0.0471 | MAE=0.0350 | ETA=4.0s
# Epoch 5/50 | Val R2=0.5830 | EMA R2=0.5712 ★Best★ | RMSE=0.0471 | MAE=0.0350 | ETA=3.8s
# Epoch 6/50 | Val R2=0.5833 | EMA R2=0.5773 ★Best★ | RMSE=0.0471 | MAE=0.0349 | ETA=3.7s
# Epoch 7/50 | Val R2=0.5844 | EMA R2=0.5808 ★Best★ | RMSE=0.0470 | MAE=0.0349 | ETA=3.6s
# Epoch 8/50 | Val R2=0.5846 | EMA R2=0.5827 ★Best★ | RMSE=0.0470 | MAE=0.0349 | ETA=3.6s
# Epoch 9/50 | Val R2=0.5846 | EMA R2=0.5836 ★Best★ | RMSE=0.0470 | MAE=0.0349 | ETA=3.5s
# Epoch 10/50 | Val R2=0.5846 | EMA R2=0.5841 ★Best★ | RMSE=0.0470 | MAE=0.0349 | ETA=3.4s
# Epoch 11/50 | Val R2=0.5846 | EMA R2=0.5843 ★Best★ | RMSE=0.0470 | MAE=0.0349 | ETA=3.4s
# Epoch 12/50 | Val R2=0.5846 | EMA R2=0.5845 ★Best★ | RMSE=0.0470 | MAE=0.0349 | ETA=3.4s
# Epoch 13/50 | Val R2=0.5846 | EMA R2=0.5845  | RMSE=0.0470 | MAE=0.0349 | ETA=3.3s
# ⏹ EarlyStopping Triggered (best_rounds=600)
# ✅ Plant 하동변전소 평가 완료 | R2=0.5846 | RMSE=0.0470 | MAE=0.0349
#
# 🌱 Plant 1차 학습 시작: 하동보건소 | train size: 78864
# Epoch 1/50 | Val R2=0.4125 | EMA R2=0.4125 ★Best★ | RMSE=0.0464 | MAE=0.0388 | ETA=3.9s
# Epoch 2/50 | Val R2=0.5260 | EMA R2=0.4693 ★Best★ | RMSE=0.0416 | MAE=0.0342 | ETA=3.7s
# Epoch 3/50 | Val R2=0.5681 | EMA R2=0.5187 ★Best★ | RMSE=0.0397 | MAE=0.0321 | ETA=3.6s
# Epoch 4/50 | Val R2=0.5709 | EMA R2=0.5448 ★Best★ | RMSE=0.0396 | MAE=0.0320 | ETA=3.4s
# Epoch 5/50 | Val R2=0.5710 | EMA R2=0.5579 ★Best★ | RMSE=0.0396 | MAE=0.0320 | ETA=3.3s
# Epoch 6/50 | Val R2=0.5710 | EMA R2=0.5645 ★Best★ | RMSE=0.0396 | MAE=0.0320 | ETA=3.2s
# Epoch 7/50 | Val R2=0.5716 | EMA R2=0.5680 ★Best★ | RMSE=0.0396 | MAE=0.0320 | ETA=3.2s
# Epoch 8/50 | Val R2=0.5720 | EMA R2=0.5700 ★Best★ | RMSE=0.0396 | MAE=0.0319 | ETA=3.1s
# Epoch 9/50 | Val R2=0.5720 | EMA R2=0.5710 ★Best★ | RMSE=0.0396 | MAE=0.0319 | ETA=3.1s
# Epoch 10/50 | Val R2=0.5720 | EMA R2=0.5715 ★Best★ | RMSE=0.0396 | MAE=0.0319 | ETA=3.1s
# Epoch 11/50 | Val R2=0.5724 | EMA R2=0.5719 ★Best★ | RMSE=0.0395 | MAE=0.0319 | ETA=3.1s
# Epoch 12/50 | Val R2=0.5723 | EMA R2=0.5721 ★Best★ | RMSE=0.0395 | MAE=0.0319 | ETA=3.0s
# Epoch 13/50 | Val R2=0.5723 | EMA R2=0.5722  | RMSE=0.0395 | MAE=0.0319 | ETA=3.0s
# ⏹ EarlyStopping Triggered (best_rounds=600)
# ✅ Plant 하동보건소 평가 완료 | R2=0.5723 | RMSE=0.0395 | MAE=0.0319
#
# 🌱 Plant 1차 학습 시작: 하동본부 | train size: 78864
# Epoch 1/50 | Val R2=0.0000 | EMA R2=0.0000 ★Best★ | RMSE=9.8162 | MAE=8.3322 | ETA=5.0s
# Epoch 2/50 | Val R2=0.2032 | EMA R2=0.1016 ★Best★ | RMSE=8.2450 | MAE=6.7217 | ETA=5.3s
# Epoch 3/50 | Val R2=0.3490 | EMA R2=0.2253 ★Best★ | RMSE=7.4523 | MAE=5.8517 | ETA=5.7s
# Epoch 4/50 | Val R2=0.4262 | EMA R2=0.3258 ★Best★ | RMSE=6.9964 | MAE=5.3517 | ETA=6.2s
# Epoch 5/50 | Val R2=0.4707 | EMA R2=0.3982 ★Best★ | RMSE=6.7198 | MAE=5.0623 | ETA=6.8s
# Epoch 6/50 | Val R2=0.4961 | EMA R2=0.4472 ★Best★ | RMSE=6.5567 | MAE=4.9086 | ETA=7.1s
# Epoch 7/50 | Val R2=0.5095 | EMA R2=0.4783 ★Best★ | RMSE=6.4688 | MAE=4.8215 | ETA=7.4s
# Epoch 8/50 | Val R2=0.5200 | EMA R2=0.4992 ★Best★ | RMSE=6.3991 | MAE=4.7586 | ETA=7.6s
# Epoch 9/50 | Val R2=0.5273 | EMA R2=0.5132 ★Best★ | RMSE=6.3505 | MAE=4.7094 | ETA=8.0s
# Epoch 10/50 | Val R2=0.5328 | EMA R2=0.5230 ★Best★ | RMSE=6.3134 | MAE=4.6695 | ETA=8.2s
# Epoch 11/50 | Val R2=0.5344 | EMA R2=0.5287 ★Best★ | RMSE=6.3027 | MAE=4.6569 | ETA=8.3s
# Epoch 12/50 | Val R2=0.5354 | EMA R2=0.5321 ★Best★ | RMSE=6.2955 | MAE=4.6495 | ETA=8.4s
# Epoch 13/50 | Val R2=0.5365 | EMA R2=0.5343 ★Best★ | RMSE=6.2881 | MAE=4.6435 | ETA=8.5s
# Epoch 14/50 | Val R2=0.5386 | EMA R2=0.5364 ★Best★ | RMSE=6.2742 | MAE=4.6321 | ETA=8.5s
# Epoch 15/50 | Val R2=0.5393 | EMA R2=0.5379 ★Best★ | RMSE=6.2691 | MAE=4.6268 | ETA=8.4s
# Epoch 16/50 | Val R2=0.5395 | EMA R2=0.5387 ★Best★ | RMSE=6.2679 | MAE=4.6259 | ETA=8.4s
# Epoch 17/50 | Val R2=0.5396 | EMA R2=0.5391 ★Best★ | RMSE=6.2673 | MAE=4.6246 | ETA=8.3s
# Epoch 18/50 | Val R2=0.5401 | EMA R2=0.5396 ★Best★ | RMSE=6.2641 | MAE=4.6215 | ETA=8.2s
# Epoch 19/50 | Val R2=0.5404 | EMA R2=0.5400 ★Best★ | RMSE=6.2617 | MAE=4.6188 | ETA=8.1s
# Epoch 20/50 | Val R2=0.5404 | EMA R2=0.5402 ★Best★ | RMSE=6.2619 | MAE=4.6190 | ETA=8.1s
# Epoch 21/50 | Val R2=0.5406 | EMA R2=0.5404 ★Best★ | RMSE=6.2606 | MAE=4.6180 | ETA=7.9s
# Epoch 22/50 | Val R2=0.5404 | EMA R2=0.5404  | RMSE=6.2614 | MAE=4.6190 | ETA=7.7s
# ⏹ EarlyStopping Triggered (best_rounds=1050)
# ✅ Plant 하동본부 평가 완료 | R2=0.5406 | RMSE=6.2606 | MAE=4.6180
#
# 🌱 Plant 1차 학습 시작: 하동정수장 | train size: 78864
# Epoch 1/50 | Val R2=0.0872 | EMA R2=0.0872 ★Best★ | RMSE=0.1138 | MAE=0.0923 | ETA=4.3s
# Epoch 2/50 | Val R2=0.1648 | EMA R2=0.1260 ★Best★ | RMSE=0.1088 | MAE=0.0841 | ETA=4.3s
# Epoch 3/50 | Val R2=0.2332 | EMA R2=0.1796 ★Best★ | RMSE=0.1043 | MAE=0.0784 | ETA=4.3s
# Epoch 4/50 | Val R2=0.2604 | EMA R2=0.2200 ★Best★ | RMSE=0.1024 | MAE=0.0761 | ETA=4.3s
# Epoch 5/50 | Val R2=0.2638 | EMA R2=0.2419 ★Best★ | RMSE=0.1022 | MAE=0.0758 | ETA=4.2s
# Epoch 6/50 | Val R2=0.2648 | EMA R2=0.2534 ★Best★ | RMSE=0.1021 | MAE=0.0758 | ETA=4.1s
# Epoch 7/50 | Val R2=0.2659 | EMA R2=0.2596 ★Best★ | RMSE=0.1020 | MAE=0.0757 | ETA=4.0s
# Epoch 8/50 | Val R2=0.2660 | EMA R2=0.2628 ★Best★ | RMSE=0.1020 | MAE=0.0757 | ETA=4.0s
# Epoch 9/50 | Val R2=0.2664 | EMA R2=0.2646 ★Best★ | RMSE=0.1020 | MAE=0.0756 | ETA=3.9s
# Epoch 10/50 | Val R2=0.2665 | EMA R2=0.2655 ★Best★ | RMSE=0.1020 | MAE=0.0756 | ETA=3.9s
# Epoch 11/50 | Val R2=0.2664 | EMA R2=0.2660 ★Best★ | RMSE=0.1020 | MAE=0.0756 | ETA=3.8s
# Epoch 12/50 | Val R2=0.2664 | EMA R2=0.2662 ★Best★ | RMSE=0.1020 | MAE=0.0756 | ETA=3.7s
# Epoch 13/50 | Val R2=0.2664 | EMA R2=0.2663 ★Best★ | RMSE=0.1020 | MAE=0.0756 | ETA=3.8s
# Epoch 14/50 | Val R2=0.2664 | EMA R2=0.2663  | RMSE=0.1020 | MAE=0.0756 | ETA=3.7s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 하동정수장 평가 완료 | R2=0.2664 | RMSE=0.1020 | MAE=0.0756
#
# 🌱 Plant 1차 학습 시작: 하동하수처리장 | train size: 78864
# Epoch 1/50 | Val R2=0.4731 | EMA R2=0.4731 ★Best★ | RMSE=0.0538 | MAE=0.0420 | ETA=4.2s
# Epoch 2/50 | Val R2=0.5787 | EMA R2=0.5259 ★Best★ | RMSE=0.0482 | MAE=0.0365 | ETA=4.1s
# Epoch 3/50 | Val R2=0.6217 | EMA R2=0.5738 ★Best★ | RMSE=0.0456 | MAE=0.0340 | ETA=4.0s
# Epoch 4/50 | Val R2=0.6246 | EMA R2=0.5992 ★Best★ | RMSE=0.0455 | MAE=0.0338 | ETA=3.9s
# Epoch 5/50 | Val R2=0.6261 | EMA R2=0.6127 ★Best★ | RMSE=0.0454 | MAE=0.0338 | ETA=3.8s
# Epoch 6/50 | Val R2=0.6266 | EMA R2=0.6196 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.7s
# Epoch 7/50 | Val R2=0.6266 | EMA R2=0.6231 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.6s
# Epoch 8/50 | Val R2=0.6268 | EMA R2=0.6250 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.6s
# Epoch 9/50 | Val R2=0.6268 | EMA R2=0.6259 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.7s
# Epoch 10/50 | Val R2=0.6268 | EMA R2=0.6263 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.6s
# Epoch 11/50 | Val R2=0.6270 | EMA R2=0.6267 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.7s
# Epoch 12/50 | Val R2=0.6273 | EMA R2=0.6270 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.7s
# Epoch 13/50 | Val R2=0.6273 | EMA R2=0.6271 ★Best★ | RMSE=0.0453 | MAE=0.0337 | ETA=3.7s
# Epoch 14/50 | Val R2=0.6273 | EMA R2=0.6272  | RMSE=0.0453 | MAE=0.0337 | ETA=3.6s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 하동하수처리장 평가 완료 | R2=0.6273 | RMSE=0.0453 | MAE=0.0337
#
# 🌱 Plant 1차 학습 시작: 행원소수력 | train size: 78864
# Epoch 1/50 | Val R2=0.3134 | EMA R2=0.3134 ★Best★ | RMSE=0.0139 | MAE=0.0131 | ETA=3.2s
# Epoch 2/50 | Val R2=0.5348 | EMA R2=0.4241 ★Best★ | RMSE=0.0114 | MAE=0.0096 | ETA=3.1s
# Epoch 3/50 | Val R2=0.5919 | EMA R2=0.5080 ★Best★ | RMSE=0.0107 | MAE=0.0083 | ETA=3.3s
# Epoch 4/50 | Val R2=0.6105 | EMA R2=0.5593 ★Best★ | RMSE=0.0105 | MAE=0.0077 | ETA=3.2s
# Epoch 5/50 | Val R2=0.6107 | EMA R2=0.5850 ★Best★ | RMSE=0.0105 | MAE=0.0077 | ETA=3.1s
# Epoch 6/50 | Val R2=0.6114 | EMA R2=0.5982 ★Best★ | RMSE=0.0104 | MAE=0.0077 | ETA=3.2s
# Epoch 7/50 | Val R2=0.6113 | EMA R2=0.6047 ★Best★ | RMSE=0.0104 | MAE=0.0077 | ETA=3.2s
# Epoch 8/50 | Val R2=0.6111 | EMA R2=0.6079 ★Best★ | RMSE=0.0105 | MAE=0.0077 | ETA=3.1s
# Epoch 9/50 | Val R2=0.6112 | EMA R2=0.6096 ★Best★ | RMSE=0.0104 | MAE=0.0077 | ETA=3.1s
# Epoch 10/50 | Val R2=0.6111 | EMA R2=0.6103 ★Best★ | RMSE=0.0105 | MAE=0.0077 | ETA=3.1s
# Epoch 11/50 | Val R2=0.6110 | EMA R2=0.6107 ★Best★ | RMSE=0.0105 | MAE=0.0077 | ETA=3.1s
# Epoch 12/50 | Val R2=0.6113 | EMA R2=0.6110 ★Best★ | RMSE=0.0104 | MAE=0.0077 | ETA=3.1s
# Epoch 13/50 | Val R2=0.6114 | EMA R2=0.6112 ★Best★ | RMSE=0.0104 | MAE=0.0077 | ETA=3.0s
# Epoch 14/50 | Val R2=0.6114 | EMA R2=0.6113  | RMSE=0.0104 | MAE=0.0077 | ETA=3.0s
# ⏹ EarlyStopping Triggered (best_rounds=650)
# ✅ Plant 행원소수력 평가 완료 | R2=0.6114 | RMSE=0.0104 | MAE=0.0077
#
# 🌿 Region 고산 warm start: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\남제주소내\best.json
# 🔄 Resume from: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\남제주소내\best.json
# Epoch 1/10 | Val R2=0.6339 | EMA R2=0.6339 ★Best★ | RMSE=0.1824 | MAE=0.1197 | ETA=0.0s
# Epoch 2/10 | Val R2=0.6339 | EMA R2=0.6339  | RMSE=0.1824 | MAE=0.1197 | ETA=0.0s
# Epoch 3/10 | Val R2=0.6341 | EMA R2=0.6340  | RMSE=0.1823 | MAE=0.1196 | ETA=0.0s
# Epoch 4/10 | Val R2=0.6342 | EMA R2=0.6341 ★Best★ | RMSE=0.1823 | MAE=0.1196 | ETA=0.0s
# Epoch 5/10 | Val R2=0.6342 | EMA R2=0.6342  | RMSE=0.1823 | MAE=0.1196 | ETA=0.0s
# Epoch 6/10 | Val R2=0.6343 | EMA R2=0.6343 ★Best★ | RMSE=0.1823 | MAE=0.1195 | ETA=0.0s
# Epoch 7/10 | Val R2=0.6341 | EMA R2=0.6342  | RMSE=0.1823 | MAE=0.1195 | ETA=0.0s
# Epoch 8/10 | Val R2=0.6342 | EMA R2=0.6342  | RMSE=0.1823 | MAE=0.1195 | ETA=0.0s
# Epoch 9/10 | Val R2=0.6341 | EMA R2=0.6341  | RMSE=0.1823 | MAE=0.1195 | ETA=0.0s
# ⏹ EarlyStopping Triggered (best_rounds=1630)
# ✅ Region 고산 평가 완료 | R2=0.6343 | RMSE=0.1823 | MAE=0.1195
#
# 🌿 Region 광양시 warm start: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\하동공설운동장\best.json
# 🔄 Resume from: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\하동공설운동장\best.json
# Epoch 1/10 | Val R2=0.5127 | EMA R2=0.5127 ★Best★ | RMSE=6.0946 | MAE=2.3329 | ETA=1.0s
# Epoch 2/10 | Val R2=0.6809 | EMA R2=0.5968 ★Best★ | RMSE=4.9318 | MAE=1.6250 | ETA=0.0s
# Epoch 3/10 | Val R2=0.7182 | EMA R2=0.6575 ★Best★ | RMSE=4.6349 | MAE=1.4276 | ETA=0.0s
# Epoch 4/10 | Val R2=0.7347 | EMA R2=0.6961 ★Best★ | RMSE=4.4974 | MAE=1.3655 | ETA=0.0s
# Epoch 5/10 | Val R2=0.7443 | EMA R2=0.7202 ★Best★ | RMSE=4.4154 | MAE=1.3305 | ETA=0.0s
# Epoch 6/10 | Val R2=0.7485 | EMA R2=0.7344 ★Best★ | RMSE=4.3782 | MAE=1.3137 | ETA=0.0s
# Epoch 7/10 | Val R2=0.7506 | EMA R2=0.7425 ★Best★ | RMSE=4.3604 | MAE=1.3060 | ETA=0.0s
# Epoch 8/10 | Val R2=0.7516 | EMA R2=0.7470 ★Best★ | RMSE=4.3517 | MAE=1.3020 | ETA=0.0s
# Epoch 9/10 | Val R2=0.7523 | EMA R2=0.7496 ★Best★ | RMSE=4.3456 | MAE=1.2993 | ETA=0.0s
# Epoch 10/10 | Val R2=0.7527 | EMA R2=0.7512 ★Best★ | RMSE=4.3418 | MAE=1.2975 | ETA=0.0s
# ✅ Region 광양시 평가 완료 | R2=0.7527 | RMSE=4.3418 | MAE=1.2975
#
# 🌿 Region 부산 warm start: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\부산운동장\best.json
# 🔄 Resume from: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\부산운동장\best.json
# Epoch 1/10 | Val R2=0.6761 | EMA R2=0.6761 ★Best★ | RMSE=1.2902 | MAE=0.7856 | ETA=0.0s
# Epoch 2/10 | Val R2=0.6807 | EMA R2=0.6784 ★Best★ | RMSE=1.2812 | MAE=0.6165 | ETA=0.0s
# Epoch 3/10 | Val R2=0.6889 | EMA R2=0.6837 ★Best★ | RMSE=1.2645 | MAE=0.5777 | ETA=0.0s
# Epoch 4/10 | Val R2=0.6964 | EMA R2=0.6901 ★Best★ | RMSE=1.2492 | MAE=0.5617 | ETA=0.0s
# Epoch 5/10 | Val R2=0.7023 | EMA R2=0.6962 ★Best★ | RMSE=1.2370 | MAE=0.5519 | ETA=0.0s
# Epoch 6/10 | Val R2=0.7069 | EMA R2=0.7015 ★Best★ | RMSE=1.2274 | MAE=0.5451 | ETA=0.0s
# Epoch 7/10 | Val R2=0.7100 | EMA R2=0.7058 ★Best★ | RMSE=1.2209 | MAE=0.5400 | ETA=0.0s
# Epoch 8/10 | Val R2=0.7123 | EMA R2=0.7090 ★Best★ | RMSE=1.2161 | MAE=0.5368 | ETA=0.0s
# Epoch 9/10 | Val R2=0.7130 | EMA R2=0.7110 ★Best★ | RMSE=1.2146 | MAE=0.5358 | ETA=0.0s
# Epoch 10/10 | Val R2=0.7139 | EMA R2=0.7125 ★Best★ | RMSE=1.2126 | MAE=0.5345 | ETA=0.0s
# ✅ Region 부산 평가 완료 | R2=0.7139 | RMSE=1.2126 | MAE=0.5345
#
# 🌿 Region 성산 warm start: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\행원소수력\best.json
# 🔄 Resume from: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\행원소수력\best.json
# Epoch 1/10 | Val R2=0.5569 | EMA R2=0.5569 ★Best★ | RMSE=1.2458 | MAE=0.7060 | ETA=0.3s
# Epoch 2/10 | Val R2=0.6902 | EMA R2=0.6236 ★Best★ | RMSE=1.0417 | MAE=0.5608 | ETA=0.0s
# Epoch 3/10 | Val R2=0.6999 | EMA R2=0.6617 ★Best★ | RMSE=1.0254 | MAE=0.5431 | ETA=0.0s
# Epoch 4/10 | Val R2=0.7007 | EMA R2=0.6812 ★Best★ | RMSE=1.0239 | MAE=0.5412 | ETA=0.0s
# Epoch 5/10 | Val R2=0.7005 | EMA R2=0.6909 ★Best★ | RMSE=1.0243 | MAE=0.5411 | ETA=0.0s
# Epoch 6/10 | Val R2=0.7005 | EMA R2=0.6957 ★Best★ | RMSE=1.0242 | MAE=0.5412 | ETA=0.0s
# Epoch 7/10 | Val R2=0.7005 | EMA R2=0.6981 ★Best★ | RMSE=1.0243 | MAE=0.5412 | ETA=0.0s
# Epoch 8/10 | Val R2=0.7005 | EMA R2=0.6993 ★Best★ | RMSE=1.0243 | MAE=0.5411 | ETA=0.0s
# Epoch 9/10 | Val R2=0.7004 | EMA R2=0.6999 ★Best★ | RMSE=1.0244 | MAE=0.5410 | ETA=0.0s
# Epoch 10/10 | Val R2=0.7005 | EMA R2=0.7002 ★Best★ | RMSE=1.0244 | MAE=0.5410 | ETA=0.0s
# ✅ Region 성산 평가 완료 | R2=0.7005 | RMSE=1.0244 | MAE=0.5410
#
# 🌿 Region 영월 warm start: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\영월철도부지\best.json
# 🔄 Resume from: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\영월철도부지\best.json
# Epoch 1/10 | Val R2=0.6942 | EMA R2=0.6942 ★Best★ | RMSE=1.0306 | MAE=0.7527 | ETA=0.2s
# Epoch 2/10 | Val R2=0.6941 | EMA R2=0.6941  | RMSE=1.0306 | MAE=0.7525 | ETA=0.0s
# Epoch 3/10 | Val R2=0.6943 | EMA R2=0.6942  | RMSE=1.0304 | MAE=0.7521 | ETA=0.0s
# Epoch 4/10 | Val R2=0.6942 | EMA R2=0.6942  | RMSE=1.0304 | MAE=0.7523 | ETA=0.0s
# ⏹ EarlyStopping Triggered (best_rounds=730)
# ✅ Region 영월 평가 완료 | R2=0.6942 | RMSE=1.0306 | MAE=0.7527
#
# 🌿 Region 울진 warm start: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\삼척소내\best.json
# 🔄 Resume from: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\삼척소내\best.json
# Epoch 1/10 | Val R2=0.6539 | EMA R2=0.6539 ★Best★ | RMSE=6.1051 | MAE=4.4383 | ETA=0.0s
# Epoch 2/10 | Val R2=0.6543 | EMA R2=0.6541 ★Best★ | RMSE=6.1016 | MAE=4.4336 | ETA=0.0s
# Epoch 3/10 | Val R2=0.6541 | EMA R2=0.6541  | RMSE=6.1031 | MAE=4.4365 | ETA=0.0s
# Epoch 4/10 | Val R2=0.6542 | EMA R2=0.6542  | RMSE=6.1025 | MAE=4.4356 | ETA=0.0s
# Epoch 5/10 | Val R2=0.6542 | EMA R2=0.6542  | RMSE=6.1024 | MAE=4.4343 | ETA=0.0s
# ⏹ EarlyStopping Triggered (best_rounds=1060)
# ✅ Region 울진 평가 완료 | R2=0.6543 | RMSE=6.1016 | MAE=4.4336
#
# 🌿 Region 인천 warm start: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\신인천해수구취수구\best.json
# 🔄 Resume from: C:\ESG_Project1\xgboost\output\1w_feat22_rep\checkpoints\plant\신인천해수구취수구\best.json
# Epoch 1/10 | Val R2=0.5334 | EMA R2=0.5334 ★Best★ | RMSE=1.3465 | MAE=0.9698 | ETA=0.0s
# Epoch 2/10 | Val R2=0.5625 | EMA R2=0.5480 ★Best★ | RMSE=1.3038 | MAE=0.9286 | ETA=0.0s
# Epoch 3/10 | Val R2=0.5698 | EMA R2=0.5589 ★Best★ | RMSE=1.2929 | MAE=0.9138 | ETA=0.0s
# Epoch 4/10 | Val R2=0.5784 | EMA R2=0.5686 ★Best★ | RMSE=1.2800 | MAE=0.8968 | ETA=0.0s
# Epoch 5/10 | Val R2=0.5850 | EMA R2=0.5768 ★Best★ | RMSE=1.2699 | MAE=0.8828 | ETA=0.0s
# Epoch 6/10 | Val R2=0.5872 | EMA R2=0.5820 ★Best★ | RMSE=1.2665 | MAE=0.8760 | ETA=0.0s
# Epoch 7/10 | Val R2=0.5885 | EMA R2=0.5852 ★Best★ | RMSE=1.2645 | MAE=0.8725 | ETA=0.0s
# Epoch 8/10 | Val R2=0.5890 | EMA R2=0.5871 ★Best★ | RMSE=1.2637 | MAE=0.8708 | ETA=0.0s
# Epoch 9/10 | Val R2=0.5897 | EMA R2=0.5884 ★Best★ | RMSE=1.2626 | MAE=0.8692 | ETA=0.0s
# Epoch 10/10 | Val R2=0.5898 | EMA R2=0.5891 ★Best★ | RMSE=1.2625 | MAE=0.8688 | ETA=0.0s
# ✅ Region 인천 평가 완료 | R2=0.5898 | RMSE=1.2625 | MAE=0.8688
#
# ===== [VALID] 최종 결과(가중 평균) =====
# Plant        R²=0.5698  RMSE=0.9352  MAE=0.6809
# Region       R²=0.7123  RMSE=2.6185  MAE=0.9872
# Region(보정) R²=0.7268  RMSE=2.5636  MAE=0.9994
#
# ===== [TEST] 최종 결과(가중 평균) =====
# Plant        R²=0.6136  RMSE=1.0276  MAE=0.7435
# Region       R²=0.6743  RMSE=2.3406  MAE=1.0243
# Region(보정) R²=0.6910  RMSE=2.2917  MAE=1.0337
#
# 🏁 완료
