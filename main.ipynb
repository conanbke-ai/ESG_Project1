# %% [markdown]
# 연도를 입력하여 main 함수 실행 파일

# %%
import sys
import os
# ===== 모듈 경로 추가 =====
sys.path.append(r"C:\ESG_Project1\file")

# ===== 모듈 임포트 =====
from auto_save_solar import download_solar_data

# %%
# ===== 설정 =====
BASE_PATH = r"C:\ESG_Project1\file\solar_data_file"
MAX_RETRY = 3
start_year = 2022
end_year = 2025

# ===== 실행 =====
for year in range(start_year, end_year + 1):
    print(f"\n========== {year}년 데이터 다운로드 시작 ==========")
    download_solar_data(BASE_PATH, year, MAX_RETRY)
print("\n🎉 모든 연도 CSV 파일 다운로드 완료!")

for year in range(start_year, end_year + 1):
    print(f"\n========== {year}년 XGBoost 학습 시작 ==========")
    train_xgboost_by_year(BASE_PATH, year)
print("\n🎉 모든 연도 XGBoost 학습 완료!")
# Out:
# ========== 2022년 데이터 다운로드 시작 ==========
# ▶ 2022-01 (20220101 ~ 20220131) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_01.csv
# ▶ 2022-02 (20220201 ~ 20220228) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_02.csv
# ▶ 2022-03 (20220301 ~ 20220331) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_03.csv
# ▶ 2022-04 (20220401 ~ 20220430) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_04.csv
# ▶ 2022-05 (20220501 ~ 20220531) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_05.csv
# ▶ 2022-06 (20220601 ~ 20220630) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_06.csv
# ▶ 2022-07 (20220701 ~ 20220731) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_07.csv
# ▶ 2022-08 (20220801 ~ 20220831) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_08.csv
# ▶ 2022-09 (20220901 ~ 20220930) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_09.csv
# ▶ 2022-10 (20221001 ~ 20221031) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_10.csv
# ▶ 2022-11 (20221101 ~ 20221130) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_11.csv
# ▶ 2022-12 (20221201 ~ 20221231) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2022\남동발전량_2022_12.csv
#
# 🎉 2022년 CSV 파일이 'C:\ESG_Project1\file\solar_data_file\2022'에 저장 완료되었습니다.
#
# ========== 2023년 데이터 다운로드 시작 ==========
# ▶ 2023-01 (20230101 ~ 20230131) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_01.csv
# ▶ 2023-02 (20230201 ~ 20230228) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_02.csv
# ▶ 2023-03 (20230301 ~ 20230331) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_03.csv
# ▶ 2023-04 (20230401 ~ 20230430) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_04.csv
# ▶ 2023-05 (20230501 ~ 20230531) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_05.csv
# ▶ 2023-06 (20230601 ~ 20230630) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_06.csv
# ▶ 2023-07 (20230701 ~ 20230731) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_07.csv
# ▶ 2023-08 (20230801 ~ 20230831) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_08.csv
# ▶ 2023-09 (20230901 ~ 20230930) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_09.csv
# ▶ 2023-10 (20231001 ~ 20231031) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_10.csv
# ▶ 2023-11 (20231101 ~ 20231130) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_11.csv
# ▶ 2023-12 (20231201 ~ 20231231) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2023\남동발전량_2023_12.csv
#
# 🎉 2023년 CSV 파일이 'C:\ESG_Project1\file\solar_data_file\2023'에 저장 완료되었습니다.
#
# ========== 2024년 데이터 다운로드 시작 ==========
# ▶ 2024-01 (20240101 ~ 20240131) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_01.csv
# ▶ 2024-02 (20240201 ~ 20240229) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_02.csv
# ▶ 2024-03 (20240301 ~ 20240331) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_03.csv
# ▶ 2024-04 (20240401 ~ 20240430) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_04.csv
# ▶ 2024-05 (20240501 ~ 20240531) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_05.csv
# ▶ 2024-06 (20240601 ~ 20240630) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_06.csv
# ▶ 2024-07 (20240701 ~ 20240731) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_07.csv
# ▶ 2024-08 (20240801 ~ 20240831) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_08.csv
# ▶ 2024-09 (20240901 ~ 20240930) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_09.csv
# ▶ 2024-10 (20241001 ~ 20241031) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_10.csv
# ▶ 2024-11 (20241101 ~ 20241130) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_11.csv
# ▶ 2024-12 (20241201 ~ 20241231) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2024\남동발전량_2024_12.csv
#
# 🎉 2024년 CSV 파일이 'C:\ESG_Project1\file\solar_data_file\2024'에 저장 완료되었습니다.
#
# ========== 2025년 데이터 다운로드 시작 ==========
# ▶ 2025-01 (20250101 ~ 20250131) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2025\남동발전량_2025_01.csv
# ▶ 2025-02 (20250201 ~ 20250228) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2025\남동발전량_2025_02.csv
# ▶ 2025-03 (20250301 ~ 20250331) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2025\남동발전량_2025_03.csv
# ▶ 2025-04 (20250401 ~ 20250430) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2025\남동발전량_2025_04.csv
# ▶ 2025-05 (20250501 ~ 20250531) 조회 중...
# ✅ 저장 완료 → C:\ESG_Project1\file\solar_data_file\2025\남동발전량_2025_05.csv
# ▶ 2025-06 (20250601 ~ 20250630) 조회 중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       8 for year in range(start_year, end_year + 1):
#       9     print(f"\n========== {year}년 데이터 다운로드 시작 ==========")
# ---> 10     download_solar_data(BASE_PATH, year, MAX_RETRY)
#      12 print("\n🎉 모든 연도 CSV 파일 다운로드 완료!")
#
# File C:\ESG_Project1\file\auto_save_solar.py:74, in download_solar_data(base_path, year, max_retry)
#      72 search_btn = driver.find_element(By.XPATH, "//a[contains(@href, 'goSubmit') or contains(text(),'조회')]")
#      73 search_btn.click()
# ---> 74 time.sleep(3)
#      76 # CSV 다운로드 실행
#      77 driver.execute_script("goCsvDown();")
#
# KeyboardInterrupt:
